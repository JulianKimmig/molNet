# %%
from bs4 import BeautifulSoup

# %%
with open("CurrentChemID.xml","r") as f:
    bs = BeautifulSoup(f)

# %%
f = bs.findAll(recursive=False)[0].findAll(recursive=False)
print(len(f))
f[5]
# Out:
# 421672
# <chemical displayformula="C-H2-O" displayname="Formaldehyde [USP]" id="0000050000">
# <namelist>
# <descriptorname>Formaldehyde<sourcelist><source/>MeSH</sourcelist></descriptorname>
# <nameofsubstance>Methanal<sourcelist><source/>CTFA</sourcelist></nameofsubstance>
# <nameofsubstance>Formaldehyde [USP]<sourcelist><source/>NLM</sourcelist></nameofsubstance>
# <systematicname>Formaldehyde<sourcelist><source/>CCRIS<source/>ECHA<source/>EINECS<source/>EPA SRS<source/>MeSH<source/>RTECS<source/>TSCAINV</sourcelist></systematicname>
# <synonyms>AI3-26806<sourcelist><source/>NLM</sourcelist></synonyms>
# <synonyms>Aldehyd mravenci [Czech]<sourcelist><source/>RTECS</sourcelist></synonyms>
# <synonyms>Aldehyde formique [French]<sourcelist><source/>RTECS</sourcelist></synonyms>
# <synonyms>Aldehyde formique [ISO-French]<sourcelist><source/>NLM</sourcelist></synonyms>
# <synonyms>Aldeide formica [Italian]<sourcelist><source/>RTECS</sourcelist></synonyms>
# ...
