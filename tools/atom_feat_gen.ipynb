# %%
import sys
sys.path.append("../")

from molNet.utils.mol.properties import has_confomers,assert_conformers
from rdkit import Chem 
from rdkit.Chem import rdMolDescriptors,Descriptors3D ,GraphDescriptors, Descriptors, rdmolops, rdForceFieldHelpers 
import pickle
import os
import numpy as np
import json

# %%
modules=[rdMolDescriptors,Descriptors3D,GraphDescriptors,Descriptors,rdmolops]
modules={mod.__name__:mod for mod in modules}

data_to_work_pckl = "rdkit_feat_ex_data_to_work.pckl"
unsucsess_mods_pckl = "rdkit_feat_ex_unsucsess_mods.pckl"
sucsess_mods_pckl = "rdkit_feat_ex_sucsess_mods.pckl"

BAD_LIST=["^SplitMolByPDBResidues$","^SplitMolByPDBChainId$","SanitizeMol","AUTOCORR2D_[0-9]",
          "^_","_$"#internal use,
         ]
BLACK_LIST_MODULES=[rdForceFieldHelpers]
SELF_IGNORES=[
    "DescribeQuery",
    "GetBonds",
    "GetIdx",
    "GetNeighbors",
    "GetOwningMol",
    "GetPropNames",
    "GetPropsAsDict",
    "NeedsUpdatePropertyCache",
    "GetSmarts",
    "__copy__",
    "__dir__",
    "__hash__",
    "__repr__",
    "__sizeof__",
    "__str__",
    "__subclasshook__",
    "__weakref__",
    "HasQuery",
    "HasOwningMol",
]

# %%
test_smiles=[
 'C'*20,
 'C1=CC=C(C=C1)C2=CC(=CC(=C2)C3=CC(=CC4=C3SC5=CC=CC=C54)N(C6=CC=CC=C6)C7=CC=CC=C7)C8=CC(=CC9=C8SC1=CC=CC=C19)N(C1=CC=CC=C1)C1=CC=CC=C1',
 'CC(C(=O)NCCN1C(=O)C=CC(=N1)N2C=CC=N2)OC3=CC(=CC=C3)Cl',
 'CC1=C(C(NC(=S)N1)C2=CC=C(C=C2)OCC3=CC=CC=C3)C(=O)C4=CC=CC=C4',
 'CC1=CC(=CC=C1)OC(=O)C23CC4CC(C2)CC(C4)(C3)Cl',
 'COC(=O)CN1C2C(NC(=O)N2)NC1=O',
 'CC1=C(SC2=CC=CC=C12)C(=O)C[NH+]3CCN(CC3)C4=[NH+]C=C(C=C4)C(F)(F)F',
# 'CCCC=CNC1=C(C=C(C=N1)C2=CC(=CC=C2)C(=O)C(C)C3CCCCN(CC3)C(=O)OC(C)(C)C)NC4=[N+](C(=C(C=C4)OC)OC)C',
# 'CN(C1CCNC1)C(=O)/C=C/C2=CC=CC=C2Br',
# 'CN1CN(C2=CC=CC(=C21)C(=O)NC[C@H]([C@@H]3CC4=CC=CC=C4CN3)O)C5CCOCC5',
# 'CNC(=O)C1(C=C(C(=C(N1)O)O)C(=O)NCC2=CC=C(C=C2)F)CC3=CC=CC=C3',
# 'CC(C)(CCN)CNC1=CC2=C(C=C1)NC(=O)O2',
# 'C[C@H](C1=NN=C(N1C2=CC=CC=C2)SCC(=O)NC3=NC(=CS3)C4=CC=C(C=C4)F)[NH+](C)C',
# 'C1=CC(=C(C=C1[N+](=O)[O-])[N+](=O)[O-])NC(=O)C2=C(C=CN=C2)[N+](=O)[O-]',
# #'C[C@@H](CC[C@H]1[C@@H](OC(O1)(C)C)CCC=C)C[C@H]([C@@H](C)C(=O)O[C@@H](C[C@H](C)CC=C)CO[Si](C2=CC=CC=C2)(C3=CC=CC=C3)C(C)(C)C)OCOC',
# 'CC(C)(COCC=C)N=C=O',
# 'CC(C)(CNC1=CC(=CC=C1)OC2=CC=CC=C2)N.Cl',
# 'C[C@@]1([C@H]([C@@H](O[C@]1(C#N)N2C=CC(=NC2=O)N)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O',
# 'CCC(C)CCC(=O)C1CCCC2(C1)CCC(CC2)C(C)C',
# 'C(CCCN)CCC(=O)NCC(C(F)(F)F)O',
# 'CC(C)(C)C1=CC=C(C=C1)CN2C=NC(=N2)CNC',
# 'CC1=CC=C(C=C1)CSC2=NN=C(N2CC=C)C3=CC=C(C=C3)Br',
# 'CCOC1=C2C=CC=C(C2=CC3=CC=CC=C31)C(C)O',
# 'CC(=O)NC1=NC(=C(S1)C2=CC=CC=C2)CCC3=CC=C(C=C3)N=C(N)N',
# 'CC(C)(CCC(=O)NCC1=C(N=CC=C1)OC)N',
# 'CCOC1=CC=CC(=C1OCC2=CC=CC=N2)CO',
# 'C1=CSC(=C1)C(=O)NC2=C(C=C(C=C2)I)C(=O)NCCCCO',
# 'CN(C)CC=CC(=O)N1CC[C@H](C1)NC2=NC=NC3=C2C=C(N3)C#CCOC4=CC=CC=C4Cl',
# 'CC(=CCC1=CC=C(C=C1)OC)C2=CC3=CC=CC=C3C=C2',
 #'CC[C@@H](C)[I-]C1CCC(CC1)C',
# 'CC1(CC(C(N1[O])(C)C)NC(=O)C=C)C',
# 'CN(C)C1CN(CCC1O)SC',
# 'CCCC[C@]1(CS(=O)(=O)C2=C(C=C(C=C2)N(C)C)[C@@H]([C@@H]1O)C3=CC(=CC=C3)NC(=O)CCCCN(C(=O)C)C(=O)[C@@H]([C@H]([C@@H]([C@@H](COC(=O)C)OC(=O)C)OC(=O)C)OC(=O)C)OC(=O)C)CC',
# 'CN(C)CCCN(CC1=CC(=C(C=C1)Cl)Cl)S(=O)(=O)C2=CNC(=C2)C(=O)N3CCCC3',
# 'CCC1=CC=C(C=C1)CCC(=O)NC2=CC=NN2C(C)C',
# 'C1[C@@H](CC(=O)O[C@H]1C2=CC=CC=C2)C3=CC=CC=C3',
# 'CCC1=CC=C(C=C1)C(C)N[C@H](C)C2=CC=CC=C2Br',
# 'C1C=CC=CC1(C2=CC=CC=C2)C3=NN(N=N3)N=[N+]=[N-]',
# 'CCNCC1CCCN(C1)C2=NC3=CC=CC=C3N=C2C',
# 'C1=CC=C2C(=C1)C3=C(N2CC4=CC(=C(C(=C4)F)F)F)C=CC(=C3)N(C5=CC=C(C=C5)C#N)C6=CC7=C(C=C6)N(C8C7C=CC=C8)CC9=CC(=C(C(=C9)F)F)F',
# 'CC1=NC(=C(C=C1)N2C=C(C=N2)CCO)N',
# 'CCCNCC(C)(C)CCC1=CC=C(S1)Br',
# 'CNC(=O)C1[C@H]2[C@H](C(C(C1C(=O)NCC3=CC=CC=C3)O2)OC(=O)CCl)O',
# 'C1C(N(C(=O)C1I)C2=CC=C(C=C2)Cl)C3=CC(=CC=C3)OC4=NC=CN=C4',
# 'CCC1=CC2=C(C=C1)N=C(S2)N(CC3CCCO3)C(=O)C4=CC(=CC=C4)S(=O)(=O)CC',
# 'C1CCC(C1)(CCCOCC(F)(F)F)CO',
# 'CC1=CC(=C(C=C1)F)NC(=O)NC2=CC=C(C=CC2)C3=C4C(=CC=C3)NN=C4N',
# 'C1=CSC(=C1)C2=NOC(=N2)CNC(=S)NC3=CC=C(C=C3)CC#N',
# 'CC.CC.CC.CCC1CN(CCN1CC2=CC=CC=C2)C3=CC=CC(=C3C(=O)N(C)CC4=CC(=C(C=C4)OC)OC)C=O',
# 'CCCCN1CCN(C(=O)C1=O)CC2=NN=C(O2)C(C)(CC3=CC=CC=C3)N',
# 'C[C@@H](C1=CC=CC=C1)C(=O)N[C@H]2COC3=CC=CC=C3[C@@H]2OC',
# 'CCCC1=NC=CN1CC2=CC=C(C=C2)C(=NO)N',
# 'CN1C=C(N=N1)CC(C2=COC=C2)NN',
# 'CC(=O)OCC(=O)[C@]1(CC[C@@H]2[C@@]1(C[C@@H]([C@H]3[C@H]2CC(C4=CC(=O)CC[C@]34C)CN(C)C5=CC=CC=C5)OC(=O)C(F)(F)F)C)O',
# 'CCCNC(CCC1=CN=CC=C1)C2=CN(N=C2)CCC',
# 'C1=CC2=C3C(=C1NCCNCCO)C(=O)C4=C(C3=NN2CCCN)C=CN=C4',
# 'C1=CC(=C(C(=C1)Cl)NC2=NC=C(N=C2)C(=O)O)Cl',
# 'C=CCC1=CC=CC=C1OCC2=CC=C(O2)C(=O)NC3=C(C=C(C=C3)[N+](=O)[O-])C#N',
# 'CC1=C(C(=CC=C1)N(C)N)OCC2=CC=CC=N2',
# 'CCN1C=C(C(=N1)C(=O)NCC(C)C)NC(=O)C2=NN(C=C2)COC3=C(C(=CC=C3)Cl)Cl',
# 'B(C)(C1=CC=CC=C1C2=NC(=CC=C2)N)F.CC',
# 'CC(C1=C(C2=CC(=C(C=C2N=C1)OC)OC)C3=CC(=C(C=C3)OC)OC)O',
 #'CC(=C)C(=O)OCCP12(C3=CC=CC4=C3C(=CC=C4)O1)C5=CC=CC6=C5C(=CC=C6)O2',
# 'CN(C)CC1=C(C2CCC1C2)C3=CC4=C(C=CC=C4S3)OC',
# 'CC(C)C(CC1=CSC(=N1)CCOCC(F)F)N',
# 'C1CN(CCN1)CC2=CC3=C(O2)C=C(C=C3)CN',
# 'CN1C=CC=C1CN(CC2=CC=CO2)C(=O)CN(CCOC)C(=O)C=CC3=CC=CC=C3',
# 'C=C/C=C\\C=C\\C1=CC(=CC(=C1)N2C3=CC=CC=C3C4=C2C=C(C=C4)C5=NN=C(O5)C6=CC7=C(C=C6)N(C8=CC=CC=C87)C9=CC(=CC(=C9)C1=CC=CC=C1)C1=CC=CC=C1)C1=CC=CC=C1',
# 'CC(=O)C1=CC(=C(C=C1)OCCCC(=O)NC2=CC=C(C=C2)NC(=O)COC)OC',
# 'C1=CC=C(C=C1)N[C@@H](C2=CC=CC3=CC=CC=C32)[C@@H](C#N)O',
# 'CC1=CC(=C(S1)NC(=O)CSC2=NN=C(N2C)C3CCCC3)C(=O)OC',
# 'CC1=CC(=C(C=C1)O)/C=N/NC(=O)[C@H](C2=CC=CC=C2)O',
# 'C[C@H](C1=NC=C(C=C1)Cl)NC(=O)C2=CN(N=C2COC)C',
# 'C[C@H](C(=O)NC1=CC=C(C=C1)C2=CN3[C@@H](C2)C=NC4=CC(=C(C=C4C3=O)OC)OCCCCCOC5=C(C=C6C(=C5)N=C[C@@H]7CC(=CN7C6=O)C8=CC=C(C=C8)OC)OC)NC(=O)[C@@H](C(C)C)NC(=O)CCCCCN9C(=O)C=C(C9=O)OC1=CC=C(C=C1)C#N',
# 'C1=CC(=CC(=C1)C(F)(F)F)C(C2=CC(=C(C=C2)F)Cl)O',
# 'CC1=CC(=C(C=C1)C)OC2=NN=C(S2)CNCCOC',
# 'CC(C)C1=CC(=CC=C1)OC(CN)C2=CC=C(C=C2)OC',
# 'CCC1=C(N=C2C=C(C=CC2=C1)F)C/C=C\\C=C(/C=C)\\F',
# 'CCCCOC(=O)CNC(CC)(CC)CO',
# 'CC1=NC2=C(N1C3CCCC3)C=C(C=C2)C4=NC(=NCC4F)NC5=NC=C(C=C5)C6CCNCC6',
# 'CCOC(=O)COCCN1CCSC(C1C)C',
# 'C1=CC=C(C(=C1)C2=CC=C(O2)/C=C\\3/C(=NC4=CC=C(C=C4)Cl)NC(=O)S3)[N+](=O)[O-]',
# 'CCS(=O)(=O)N[C@@H](CC1=CC=CC=C1)C(=O)N2CCC[C@H]2C(=O)C(=O)[C@](C)(CCCN=C(N)N)N',
# 'C1CC(=O)NCC1NC(=O)[C@H](CCC2=CC=CC=C2)N',
# 'CC1=CC(=CC=C1)S(=O)(=O)NCC(=O)NC2=C(C=C(C(=C2)C)Cl)OC',
# 'CC(C(=O)O)N(C)C/C=C/C1=CC(=C(C=C1)F)F',
# 'CCCC(C(=O)O)NC(=O)CCN1C(=O)C(=CC2=CC=C(C=C2)OC)SC1=S',
# 'CCN(C)C(C1=CC=CC=C1)C(=O)NCCC(=O)O',
# 'CCC(CC)N1C=CC(=N1)CN2CCC(CC2)OCCN',
# 'CCNC(=S)NCCCNC1=C(C=C2C=C(C=CC2=[NH+]1)OCC)C#N',
# 'CC1CCC2=NC3=CC=CC=C3C(=C2C1)C(=O)NCC4=CN=C(C=C4)N5CCOCC5',
# 'CC1=CC=C(C=C1)N2C(=O)C3=C(C=CC(=C3)Br)N=C2NN',
# 'CC1=CC2=NC(=NN2C=C1NC)NC(=O)CCC3=CC=CC=C3',
# 'CNC1CCN(CC1)C(=O)C2=CC(=C(C(=C2)F)F)F.Cl',
# 'CC1CN(C2=C(N1C(=O)CC3=C(C=C(C=C3)F)F)C=CC(=C2)C4=CN(N=C4)C5CCNCC5)C(=O)O',
# 'COC=NC(C#N)C(=O)N',
# 'CC[C@H](C(=O)O)SC1=NN=NN1C2=CC=CC=C2',
# 'CN=C(NCCC1=CC=CC2=CC=CC=C21)NC3CCN(C3)C(=O)C4CCCC4.I',
# 'CC(CC1CCCCCN1C2CCOCC2)O',
# 'CCCN1C2=C(C=C(C=N2)C(=O)NC3=CC=CC=C3N4CCC5=CC=CC=C54)C(=O)NC1=O',
# 'CC1=CC(=CC(=C1)OCC(=O)N(CC2=CC=C(C=C2)F)[C@@H](C)C(=O)NC(C)(C)C)C',
# 'C1CN=C(N1)NN=C(C=CC2=CC=CC=C2)C=CC3=CC=C(C=C3)Cl',
# 'CN(CCCN)C1=CC(=C(C=C1)C(=O)N)Br',
# 'CN(CC1CCNCC1)C2CCCC(C2)C(F)(F)F',
# 'CCCCN1C(C(CCC1=O)C(=O)NCC(C)O)C2=CC=CC=C2OC',
# 'CC1=C(C(=NO1)C)CCNC(=NC)NCC2(CCCO2)C',
# 'CS(=O)(=O)N1CC2(C1)CN(C2)C3=CC=C(C=C3)NC4=NC=C5C(=N4)N6C=CN=C6N(C5=O)C7=C(C=CC=C7Cl)Cl',
# 'CC1CCC(N(C1)CC(=O)C2=C(C=CS2)Br)C',
# 'C1=CC=C(C=C1)S(=O)(=O)N(CC(=O)NN=CC2=C(C=CC3=CC=CC=C32)O)C4=CC(=CC=C4)Cl',
# 'CC(CNC(=NC)N1CCC(CC1)OCCCOC)COCC2=CC=CC=C2.I',
# 'CC(C)(C)C1=CC(=CC(=C1)C2=CSC(=N2)CNCC(=O)O)C(C)(C)C',
# 'C1=CC=C(C=C1)C2=CC(=CC(=N2)C3=CC=CC=C3)C4=CC=CC(=C4)C5=CC(=CC=C5)C6=CC=CC7=C6SC8=C7C9=CC=CC=C9C=C8',
# 'CCC(CC#C)NC(C/C(=N/O)/N)C1=CC=CC=C1',
# 'CC(=O)SC\\1CCNC/C1=C\\C2=NN(C=C2)CC(=O)OC(C)(C)C.C(=O)(C(F)(F)F)O',
# 'C1=C(C(=CC(=C1N(CCN=[N+]=[N-])CCCl)[N+](=O)[O-])[N+](=O)[O-])C(=O)N',
# 'CCOC1=CC=CC=C1NC(=O)N(CC(=O)N2C(C3=CC=CN3C4=CC=CC=C42)C5=CC=C(C=C5)C)C(C)C',
# 'CCN1CCC(CC1)CNS(=O)(=O)C2=CC=CC=C2CO',
# 'CCCCCCCCC(=O)N(CCCCCl)CCCO',
# 'CCNC(=NCC1CCN(C1)CC)NC2CCC(CC2)C(C)C',
# 'CCC1=NNC(=S)N1NCC2=CC(=C(C=C2Br)OCC3=CC=CC=C3F)OCC',
# 'C1C=C2C(CC3C(C2C4=COC5=C(C4)C=C(C=C5)O)C(=O)N(C3=O)C6=CC=C(C=C6)[N+](=O)[O-])C7C1C(=O)N(C7=O)C8=CC=C(C=C8)[N+](=O)[O-]',
# 'CC1=CC(=CC=C1)CCNC(=O)C2=CC(=CC(=C2)Br)N3CCN(CC3)C4=CC=NC=C4.C(=O)(C(F)(F)F)O',
# 'CC1=CC(=O)C(=C2N1C3=C(C=C(C=C3)Cl)SC(C2)C4=CSC=C4)C(=O)NCC5=CN=CC=C5',
# 'CC12C(CC3C4C(CC=C3C1C5=CC(=C(C(=C5)Br)O)OC)C(=O)N(C4=O)N(C)C6=C(C=CC(=N6)C(F)(F)F)Cl)C(=O)N(C2=O)C7=CC=CC=C7',
# 'CC1=CC=C(C=C1)CC(=O)NCC2=CC=C(C=C2)N3C=CN=C3C',
# 'CCS(=O)CCNC1CCCCC1C2CCCCC2',
# 'CC1=C(C(=NO1)C)CS(=O)(=O)CC2=NN(C=C2)C3CCCC3',
# 'CC1=CC(=C(C=C1)O)C(=O)NCCN',
# 'CC(=O)N(C)C1=CC=C(C=C1)NS(=O)(=O)C2=CC=CC=C2Cl',
# 'CCC(=O)C(C1CCCCC1)C(C)(C)O[Si](C)(C)C',
# 'CC1=C(C=CC(=C1)C(C(=O)O)NC(=O)C2=CSC(=C2C)C)F',
# 'CN(CC1=CC=CC=C1)C(=O)C2=CC(=CC=C2)NCC(=O)N(C)C3CCCCC3',
# 'CC1=CN=C(O1)CNC2=C(C=CC(=C2)S(=O)(=O)N)N',
# 'CC(C)(C(=O)O)ON=C(C1=CSC(=N1)N)C(=O)NC2[C@H]3N(C2=O)C(=C(CS3)N4C=[N+](C(CC4=N)N)C5CC5)C(=O)O',
# 'CCN(CC)CCCN1CC(=O)N[C@@H]2[C@H]1CCCC2',
# 'COC1=C(C=C(C=C1)F)S(=O)(=O)NCCN2C(=O)C=CC=N2',
]
testmols=[Chem.MolFromSmiles(s) for s in test_smiles]
testmols=[assert_conformers(m) for m in testmols]

# %%
import re
BAD_LIST = [re.compile(s) for s in BAD_LIST]

# %%
if not os.path.exists(data_to_work_pckl):
    data_to_work=[None]
    for mod_name,mod in modules.items():
        for n in vars(mod).keys():
            data_to_work.append((mod_name,n))
    with open(data_to_work_pckl,"w+b") as f:
        pickle.dump(data_to_work,f)

# %%
with open(data_to_work_pckl,"rb") as f:
    data_to_work=pickle.load(f)

if os.path.exists(unsucsess_mods_pckl):
    with open(unsucsess_mods_pckl,"rb") as f:
        unsucsess_mods=pickle.load(f)
else:
    unsucsess_mods=set()

if os.path.exists(sucsess_mods_pckl):
    with open(sucsess_mods_pckl,"rb") as f:
        sucsess_mods=pickle.load(f)
else:
    sucsess_mods=set()
    
unsucsess_mods.add(data_to_work[0])
print("bad",data_to_work[0])
data_to_work=data_to_work[1:]
with open(unsucsess_mods_pckl,"w+b") as f:
        pickle.dump(unsucsess_mods,f)
# Out:
# bad None

# %%
def error_res(n,f,e):
    pass
    
    print(n,e)

for i,d in enumerate(data_to_work):
    with open(data_to_work_pckl,"w+b") as f:
        pickle.dump(data_to_work[i:],f)
    mod=modules[d[0]]
    n=d[1]
    f=vars(mod)[n]
    if any([r.search(n) is not None for r in BAD_LIST]):
        continue
    if n.startswith("_") or isinstance(f,str):
        continue
    try:
        for a in Chem.Mol(testmols[0]).GetAtoms():
            print(d,f(a))
        #succs[n]=f
        sucsess_mods.add(d)
        with open(sucsess_mods_pckl,"w+b") as f:
            pickle.dump(sucsess_mods,f)
    except Exception as e:
        unsucsess_mods.add(d)
        with open(unsucsess_mods_pckl,"w+b") as f:
            pickle.dump(unsucsess_mods,f)
        error_res(n,f,e)
# Out:
# AtomPairsParameters Python argument types in
#     AtomPairsParameters.__init__(AtomPairsParameters, Atom)
# did not match C++ signature:
#     __init__(_object*)
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 36
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode') 481
# GetAtomPairCode Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetAtomPairCode(Atom)
# did not match C++ signature:
#     GetAtomPairCode(unsigned int atom1Code, unsigned int atom2Code, unsigned int distance, bool includeChirality=False)
# GetAtomPairFingerprint Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetAtomPairFingerprint(Atom)
# did not match C++ signature:
#     GetAtomPairFingerprint(RDKit::ROMol mol, unsigned int minLength=1, unsigned int maxLength=30, boost::python::api::object fromAtoms=0, boost::python::api::object ignoreAtoms=0, boost::python::api::object atomInvariants=0, bool includeChirality=False, bool use2D=True, int confId=-1)
# GetHashedAtomPairFingerprint Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetHashedAtomPairFingerprint(Atom)
# did not match C++ signature:
#     GetHashedAtomPairFingerprint(RDKit::ROMol mol, unsigned int nBits=2048, unsigned int minLength=1, unsigned int maxLength=30, boost::python::api::object fromAtoms=0, boost::python::api::object ignoreAtoms=0, boost::python::api::object atomInvariants=0, bool includeChirality=False, bool use2D=True, int confId=-1)
# GetHashedAtomPairFingerprintAsBitVect Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetHashedAtomPairFingerprintAsBitVect(Atom)
# did not match C++ signature:
#     GetHashedAtomPairFingerprintAsBitVect(RDKit::ROMol mol, unsigned int nBits=2048, unsigned int minLength=1, unsigned int maxLength=30, boost::python::api::object fromAtoms=0, boost::python::api::object ignoreAtoms=0, boost::python::api::object atomInvariants=0, unsigned int nBitsPerEntry=4, bool includeChirality=False, bool use2D=True, int confId=-1)
# GetTopologicalTorsionFingerprint Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetTopologicalTorsionFingerprint(Atom)
# did not match C++ signature:
#     GetTopologicalTorsionFingerprint(RDKit::ROMol mol, unsigned int targetSize=4, boost::python::api::object fromAtoms=0, boost::python::api::object ignoreAtoms=0, boost::python::api::object atomInvariants=0, bool includeChirality=False)
# GetHashedTopologicalTorsionFingerprint Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetHashedTopologicalTorsionFingerprint(Atom)
# did not match C++ signature:
#     GetHashedTopologicalTorsionFingerprint(RDKit::ROMol mol, unsigned int nBits=2048, unsigned int targetSize=4, boost::python::api::object fromAtoms=0, boost::python::api::object ignoreAtoms=0, boost::python::api::object atomInvariants=0, bool includeChirality=False)
# GetHashedTopologicalTorsionFingerprintAsBitVect Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetHashedTopologicalTorsionFingerprintAsBitVect(Atom)
# did not match C++ signature:
#     GetHashedTopologicalTorsionFingerprintAsBitVect(RDKit::ROMol mol, unsigned int nBits=2048, unsigned int targetSize=4, boost::python::api::object fromAtoms=0, boost::python::api::object ignoreAtoms=0, boost::python::api::object atomInvariants=0, unsigned int nBitsPerEntry=4, bool includeChirality=False)
# GetMorganFingerprint Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(Atom)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# GetHashedMorganFingerprint Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetHashedMorganFingerprint(Atom)
# did not match C++ signature:
#     GetHashedMorganFingerprint(RDKit::ROMol mol, unsigned int radius, unsigned int nBits=2048, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# GetMorganFingerprintAsBitVect Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprintAsBitVect(Atom)
# did not match C++ signature:
#     GetMorganFingerprintAsBitVect(RDKit::ROMol mol, unsigned int radius, unsigned int nBits=2048, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# GetConnectivityInvariants Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetConnectivityInvariants(Atom)
# did not match C++ signature:
#     GetConnectivityInvariants(RDKit::ROMol mol, bool includeRingMembership=True)
# GetFeatureInvariants Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetFeatureInvariants(Atom)
# did not match C++ signature:
#     GetFeatureInvariants(RDKit::ROMol mol)
# GetUSR Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetUSR(Atom)
# did not match C++ signature:
#     GetUSR(RDKit::ROMol mol, int confId=-1)
# GetUSRDistributions 'Atom' object has no attribute '__len__'
# GetUSRDistributionsFromPoints Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetUSRDistributionsFromPoints(Atom)
# did not match C++ signature:
#     GetUSRDistributionsFromPoints(boost::python::api::object coords, boost::python::api::object points)
# GetUSRFromDistributions 'Atom' object has no attribute '__len__'
# GetUSRScore Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetUSRScore(Atom)
# did not match C++ signature:
#     GetUSRScore(boost::python::api::object descriptor1, boost::python::api::object descriptor2, boost::python::api::object weights=[])
# GetUSRCAT Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetUSRCAT(Atom)
# did not match C++ signature:
#     GetUSRCAT(RDKit::ROMol mol, boost::python::api::object atomSelections=None, int confId=-1)
# CalcCrippenDescriptors Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcCrippenDescriptors(Atom)
# did not match C++ signature:
#     CalcCrippenDescriptors(RDKit::ROMol mol, bool includeHs=True, bool force=False)
# CalcLabuteASA Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcLabuteASA(Atom)
# did not match C++ signature:
#     CalcLabuteASA(RDKit::ROMol mol, bool includeHs=True, bool force=False)
# CalcTPSA Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcTPSA(Atom)
# did not match C++ signature:
#     CalcTPSA(RDKit::ROMol mol, bool force=False, bool includeSandP=False)
# CalcExactMolWt Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcExactMolWt(Atom)
# did not match C++ signature:
#     CalcExactMolWt(RDKit::ROMol mol, bool onlyHeavy=False)
# CalcMolFormula Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcMolFormula(Atom)
# did not match C++ signature:
#     CalcMolFormula(RDKit::ROMol mol, bool separateIsotopes=False, bool abbreviateHIsotopes=True)
# CalcNumLipinskiHBD Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumLipinskiHBD(Atom)
# did not match C++ signature:
#     CalcNumLipinskiHBD(RDKit::ROMol mol)
# CalcNumLipinskiHBA Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumLipinskiHBA(Atom)
# did not match C++ signature:
#     CalcNumLipinskiHBA(RDKit::ROMol mol)
# CalcNumHBD Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumHBD(Atom)
# did not match C++ signature:
#     CalcNumHBD(RDKit::ROMol mol)
# CalcNumHBA Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumHBA(Atom)
# did not match C++ signature:
#     CalcNumHBA(RDKit::ROMol mol)
# NumRotatableBondsOptions int() argument must be a string, a bytes-like object or a number, not 'Atom'
# CalcNumRotatableBonds Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumRotatableBonds(Atom)
# did not match C++ signature:
#     CalcNumRotatableBonds(RDKit::ROMol mol, RDKit::Descriptors::NumRotatableBondsOptions strict=rdkit.Chem.rdMolDescriptors.NumRotatableBondsOptions.Default)
#     CalcNumRotatableBonds(RDKit::ROMol mol, bool strict)
# CalcNumRings Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumRings(Atom)
# did not match C++ signature:
#     CalcNumRings(RDKit::ROMol mol)
# CalcNumAromaticRings Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumAromaticRings(Atom)
# did not match C++ signature:
#     CalcNumAromaticRings(RDKit::ROMol mol)
# CalcNumSaturatedRings Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumSaturatedRings(Atom)
# did not match C++ signature:
#     CalcNumSaturatedRings(RDKit::ROMol mol)
# CalcNumHeterocycles Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumHeterocycles(Atom)
# did not match C++ signature:
#     CalcNumHeterocycles(RDKit::ROMol mol)
# CalcNumAromaticHeterocycles Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumAromaticHeterocycles(Atom)
# did not match C++ signature:
#     CalcNumAromaticHeterocycles(RDKit::ROMol mol)
# CalcNumAromaticCarbocycles Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumAromaticCarbocycles(Atom)
# did not match C++ signature:
#     CalcNumAromaticCarbocycles(RDKit::ROMol mol)
# CalcNumSaturatedHeterocycles Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumSaturatedHeterocycles(Atom)
# did not match C++ signature:
#     CalcNumSaturatedHeterocycles(RDKit::ROMol mol)
# CalcNumSaturatedCarbocycles Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumSaturatedCarbocycles(Atom)
# did not match C++ signature:
#     CalcNumSaturatedCarbocycles(RDKit::ROMol mol)
# CalcNumAliphaticRings Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumAliphaticRings(Atom)
# did not match C++ signature:
#     CalcNumAliphaticRings(RDKit::ROMol mol)
# CalcNumAliphaticHeterocycles Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumAliphaticHeterocycles(Atom)
# did not match C++ signature:
#     CalcNumAliphaticHeterocycles(RDKit::ROMol mol)
# CalcNumAliphaticCarbocycles Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumAliphaticCarbocycles(Atom)
# did not match C++ signature:
#     CalcNumAliphaticCarbocycles(RDKit::ROMol mol)
# CalcNumHeteroatoms Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumHeteroatoms(Atom)
# did not match C++ signature:
#     CalcNumHeteroatoms(RDKit::ROMol mol)
# CalcNumAmideBonds Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumAmideBonds(Atom)
# did not match C++ signature:
#     CalcNumAmideBonds(RDKit::ROMol mol)
# CalcFractionCSP3 Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcFractionCSP3(Atom)
# did not match C++ signature:
#     CalcFractionCSP3(RDKit::ROMol mol)
# CalcChiNv Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChiNv(Atom)
# did not match C++ signature:
#     CalcChiNv(RDKit::ROMol mol, unsigned int n, bool force=False)
# CalcChi0v Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi0v(Atom)
# did not match C++ signature:
#     CalcChi0v(RDKit::ROMol mol, bool force=False)
# CalcChi1v Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi1v(Atom)
# did not match C++ signature:
#     CalcChi1v(RDKit::ROMol mol, bool force=False)
# CalcChi2v Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi2v(Atom)
# did not match C++ signature:
#     CalcChi2v(RDKit::ROMol mol, bool force=False)
# CalcChi3v Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi3v(Atom)
# did not match C++ signature:
#     CalcChi3v(RDKit::ROMol mol, bool force=False)
# CalcChi4v Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi4v(Atom)
# did not match C++ signature:
#     CalcChi4v(RDKit::ROMol mol, bool force=False)
# CalcChiNn Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChiNn(Atom)
# did not match C++ signature:
#     CalcChiNn(RDKit::ROMol mol, unsigned int n, bool force=False)
# CalcChi0n Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi0n(Atom)
# did not match C++ signature:
#     CalcChi0n(RDKit::ROMol mol, bool force=False)
# CalcChi1n Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi1n(Atom)
# did not match C++ signature:
#     CalcChi1n(RDKit::ROMol mol, bool force=False)
# CalcChi2n Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi2n(Atom)
# did not match C++ signature:
#     CalcChi2n(RDKit::ROMol mol, bool force=False)
# CalcChi3n Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi3n(Atom)
# did not match C++ signature:
#     CalcChi3n(RDKit::ROMol mol, bool force=False)
# CalcChi4n Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi4n(Atom)
# did not match C++ signature:
#     CalcChi4n(RDKit::ROMol mol, bool force=False)
# CalcHallKierAlpha Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcHallKierAlpha(Atom)
# did not match C++ signature:
#     CalcHallKierAlpha(RDKit::ROMol mol, boost::python::api::object atomContribs=None)
# CalcKappa1 Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcKappa1(Atom)
# did not match C++ signature:
#     CalcKappa1(RDKit::ROMol mol)
# CalcKappa2 Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcKappa2(Atom)
# did not match C++ signature:
#     CalcKappa2(RDKit::ROMol mol)
# CalcKappa3 Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcKappa3(Atom)
# did not match C++ signature:
#     CalcKappa3(RDKit::ROMol mol)
# CalcPhi Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcPhi(Atom)
# did not match C++ signature:
#     CalcPhi(RDKit::ROMol mol)
# GetMACCSKeysFingerprint Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMACCSKeysFingerprint(Atom)
# did not match C++ signature:
#     GetMACCSKeysFingerprint(RDKit::ROMol mol)
# GetAtomFeatures Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetAtomFeatures(Atom)
# did not match C++ signature:
#     GetAtomFeatures(RDKit::ROMol mol, int atomid, bool addchiral=False)
# CalcNumSpiroAtoms Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumSpiroAtoms(Atom)
# did not match C++ signature:
#     CalcNumSpiroAtoms(RDKit::ROMol mol, boost::python::api::object atoms=None)
# CalcNumBridgeheadAtoms Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumBridgeheadAtoms(Atom)
# did not match C++ signature:
#     CalcNumBridgeheadAtoms(RDKit::ROMol mol, boost::python::api::object atoms=None)
# CalcNumAtomStereoCenters Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumAtomStereoCenters(Atom)
# did not match C++ signature:
#     CalcNumAtomStereoCenters(RDKit::ROMol mol)
# CalcNumUnspecifiedAtomStereoCenters Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNumUnspecifiedAtomStereoCenters(Atom)
# did not match C++ signature:
#     CalcNumUnspecifiedAtomStereoCenters(RDKit::ROMol mol)
# PropertyFunctor This class cannot be instantiated from Python
# Properties 'Atom' object is not iterable
# PythonPropertyFunctor Python argument types in
#     PythonPropertyFunctor.__init__(PythonPropertyFunctor, Atom)
# did not match C++ signature:
#     __init__(_object*, _object*, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> >, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> >)
# PropertyRangeQuery This class cannot be instantiated from Python
# MakePropertyRangeQuery Python argument types in
#     rdkit.Chem.rdMolDescriptors.MakePropertyRangeQuery(Atom)
# did not match C++ signature:
#     MakePropertyRangeQuery(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > name, double min, double max)
# CalcCoulombMat Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcCoulombMat(Atom)
# did not match C++ signature:
#     CalcCoulombMat(RDKit::ROMol mol, int confId=-1)
# CalcEEMcharges Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcEEMcharges(Atom)
# did not match C++ signature:
#     CalcEEMcharges(RDKit::ROMol {lvalue} mol, int confId=-1)
# CalcWHIM Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcWHIM(Atom)
# did not match C++ signature:
#     CalcWHIM(RDKit::ROMol mol, int confId=-1, double thresh=0.001, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > CustomAtomProperty='')
# CalcGETAWAY Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcGETAWAY(Atom)
# did not match C++ signature:
#     CalcGETAWAY(RDKit::ROMol mol, int confId=-1, double precision=2, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > CustomAtomProperty='')
# CalcRDF Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcRDF(Atom)
# did not match C++ signature:
#     CalcRDF(RDKit::ROMol mol, int confId=-1, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > CustomAtomProperty='')
# CalcMORSE Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcMORSE(Atom)
# did not match C++ signature:
#     CalcMORSE(RDKit::ROMol mol, int confId=-1, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > CustomAtomProperty='')
# CalcAUTOCORR3D Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcAUTOCORR3D(Atom)
# did not match C++ signature:
#     CalcAUTOCORR3D(RDKit::ROMol mol, int confId=-1, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > CustomAtomProperty='')
# CalcPBF Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcPBF(Atom)
# did not match C++ signature:
#     CalcPBF(RDKit::ROMol mol, int confId=-1)
# CalcNPR1 Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNPR1(Atom)
# did not match C++ signature:
#     CalcNPR1(RDKit::ROMol mol, int confId=-1, bool useAtomicMasses=True, bool force=True)
# CalcNPR2 Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNPR2(Atom)
# did not match C++ signature:
#     CalcNPR2(RDKit::ROMol mol, int confId=-1, bool useAtomicMasses=True, bool force=True)
# CalcPMI1 Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcPMI1(Atom)
# did not match C++ signature:
#     CalcPMI1(RDKit::ROMol mol, int confId=-1, bool useAtomicMasses=True, bool force=True)
# CalcPMI2 Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcPMI2(Atom)
# did not match C++ signature:
#     CalcPMI2(RDKit::ROMol mol, int confId=-1, bool useAtomicMasses=True, bool force=True)
# CalcPMI3 Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcPMI3(Atom)
# did not match C++ signature:
#     CalcPMI3(RDKit::ROMol mol, int confId=-1, bool useAtomicMasses=True, bool force=True)
# CalcRadiusOfGyration Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcRadiusOfGyration(Atom)
# did not match C++ signature:
#     CalcRadiusOfGyration(RDKit::ROMol mol, int confId=-1, bool useAtomicMasses=True, bool force=True)
# CalcInertialShapeFactor Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcInertialShapeFactor(Atom)
# did not match C++ signature:
#     CalcInertialShapeFactor(RDKit::ROMol mol, int confId=-1, bool useAtomicMasses=True, bool force=True)
# CalcEccentricity Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcEccentricity(Atom)
# did not match C++ signature:
#     CalcEccentricity(RDKit::ROMol mol, int confId=-1, bool useAtomicMasses=True, bool force=True)
# CalcAsphericity Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcAsphericity(Atom)
# did not match C++ signature:
#     CalcAsphericity(RDKit::ROMol mol, int confId=-1, bool useAtomicMasses=True, bool force=True)
# CalcSpherocityIndex Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcSpherocityIndex(Atom)
# did not match C++ signature:
#     CalcSpherocityIndex(RDKit::ROMol mol, int confId=-1, bool force=True)
# CalcAUTOCORR2D Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcAUTOCORR2D(Atom)
# did not match C++ signature:
#     CalcAUTOCORR2D(RDKit::ROMol mol, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > CustomAtomProperty='')
# BCUT2D Python argument types in
#     rdkit.Chem.rdMolDescriptors.BCUT2D(Atom)
# did not match C++ signature:
#     BCUT2D(RDKit::ROMol mol, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > atom_propname)
#     BCUT2D(RDKit::ROMol mol, boost::python::tuple atom_props)
#     BCUT2D(RDKit::ROMol mol, boost::python::list atom_props)
#     BCUT2D(RDKit::ROMol mol)
# rdMolDescriptors 'module' object is not callable
# PMI1 Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcPMI1(Atom)
# did not match C++ signature:
#     CalcPMI1(RDKit::ROMol mol, int confId=-1, bool useAtomicMasses=True, bool force=True)
# PMI2 Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcPMI2(Atom)
# did not match C++ signature:
#     CalcPMI2(RDKit::ROMol mol, int confId=-1, bool useAtomicMasses=True, bool force=True)
# PMI3 Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcPMI3(Atom)
# did not match C++ signature:
#     CalcPMI3(RDKit::ROMol mol, int confId=-1, bool useAtomicMasses=True, bool force=True)
# NPR1 Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNPR1(Atom)
# did not match C++ signature:
#     CalcNPR1(RDKit::ROMol mol, int confId=-1, bool useAtomicMasses=True, bool force=True)
# NPR2 Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcNPR2(Atom)
# did not match C++ signature:
#     CalcNPR2(RDKit::ROMol mol, int confId=-1, bool useAtomicMasses=True, bool force=True)
# RadiusOfGyration Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcRadiusOfGyration(Atom)
# did not match C++ signature:
#     CalcRadiusOfGyration(RDKit::ROMol mol, int confId=-1, bool useAtomicMasses=True, bool force=True)
# InertialShapeFactor Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcInertialShapeFactor(Atom)
# did not match C++ signature:
#     CalcInertialShapeFactor(RDKit::ROMol mol, int confId=-1, bool useAtomicMasses=True, bool force=True)
# Eccentricity Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcEccentricity(Atom)
# did not match C++ signature:
#     CalcEccentricity(RDKit::ROMol mol, int confId=-1, bool useAtomicMasses=True, bool force=True)
# Asphericity Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcAsphericity(Atom)
# did not match C++ signature:
#     CalcAsphericity(RDKit::ROMol mol, int confId=-1, bool useAtomicMasses=True, bool force=True)
# SpherocityIndex Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcSpherocityIndex(Atom)
# did not match C++ signature:
#     CalcSpherocityIndex(RDKit::ROMol mol, int confId=-1, bool force=True)
# Chem 'module' object is not callable
# Graphs 'module' object is not callable
# rdchem 'module' object is not callable
# rdMolDescriptors 'module' object is not callable
# numpy 'module' object is not callable
# math 'module' object is not callable
# entropy 'module' object is not callable
# ptable 'PeriodicTable' object is not callable
# hallKierAlphas 'dict' object is not callable
# Ipc Python argument types in
#     rdkit.Chem.rdmolops.GetDistanceMatrix(Atom, int)
# did not match C++ signature:
#     GetDistanceMatrix(RDKit::ROMol {lvalue} mol, bool useBO=False, bool useAtomWts=False, bool force=False, char const* prefix='')
# HallKierAlpha Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcHallKierAlpha(Atom)
# did not match C++ signature:
#     CalcHallKierAlpha(RDKit::ROMol mol, boost::python::api::object atomContribs=None)
# Kappa1 Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcKappa1(Atom)
# did not match C++ signature:
#     CalcKappa1(RDKit::ROMol mol)
# Kappa2 Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcKappa2(Atom)
# did not match C++ signature:
#     CalcKappa2(RDKit::ROMol mol)
# Kappa3 Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcKappa3(Atom)
# did not match C++ signature:
#     CalcKappa3(RDKit::ROMol mol)
# Chi0 'Atom' object has no attribute 'GetAtoms'
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.75
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 1.75
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# ('rdkit.Chem.GraphDescriptors', 'Chi1') 0.5
# Chi0v Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi0v(Atom)
# did not match C++ signature:
#     CalcChi0v(RDKit::ROMol mol, bool force=False)
# Chi1v Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi1v(Atom)
# did not match C++ signature:
#     CalcChi1v(RDKit::ROMol mol, bool force=False)
# Chi2v Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi2v(Atom)
# did not match C++ signature:
#     CalcChi2v(RDKit::ROMol mol, bool force=False)
# Chi3v Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi3v(Atom)
# did not match C++ signature:
#     CalcChi3v(RDKit::ROMol mol, bool force=False)
# Chi4v Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi4v(Atom)
# did not match C++ signature:
#     CalcChi4v(RDKit::ROMol mol, bool force=False)
# Chi0n Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi0n(Atom)
# did not match C++ signature:
#     CalcChi0n(RDKit::ROMol mol, bool force=False)
# Chi1n Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi1n(Atom)
# did not match C++ signature:
#     CalcChi1n(RDKit::ROMol mol, bool force=False)
# Chi2n Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi2n(Atom)
# did not match C++ signature:
#     CalcChi2n(RDKit::ROMol mol, bool force=False)
# Chi3n Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi3n(Atom)
# did not match C++ signature:
#     CalcChi3n(RDKit::ROMol mol, bool force=False)
# Chi4n Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcChi4n(Atom)
# did not match C++ signature:
#     CalcChi4n(RDKit::ROMol mol, bool force=False)
# BalabanJ Python argument types in
#     rdkit.Chem.rdmolops.GetDistanceMatrix(Atom)
# did not match C++ signature:
#     GetDistanceMatrix(RDKit::ROMol {lvalue} mol, bool useBO=False, bool useAtomWts=False, bool force=False, char const* prefix='')
# BertzCT 'Atom' object has no attribute 'GetNumAtoms'
# abc 'module' object is not callable
# Chem 'module' object is not callable
# rdPartialCharges 'module' object is not callable
# rdMolDescriptors 'module' object is not callable
# MaxEStateIndex 'Atom' object has no attribute 'GetNumAtoms'
# MinEStateIndex 'Atom' object has no attribute 'GetNumAtoms'
# MaxAbsEStateIndex 'Atom' object has no attribute 'GetNumAtoms'
# MinAbsEStateIndex 'Atom' object has no attribute 'GetNumAtoms'
# qed Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(Atom)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True)
# MolWt Python argument types in
#     rdkit.Chem.rdMolDescriptors._CalcMolWt(Atom)
# did not match C++ signature:
#     _CalcMolWt(RDKit::ROMol mol, bool onlyHeavy=False)
# HeavyAtomMolWt Python argument types in
#     rdkit.Chem.rdMolDescriptors._CalcMolWt(Atom, bool)
# did not match C++ signature:
#     _CalcMolWt(RDKit::ROMol mol, bool onlyHeavy=False)
# ExactMolWt Python argument types in
#     rdkit.Chem.rdMolDescriptors.CalcExactMolWt(Atom)
# did not match C++ signature:
#     CalcExactMolWt(RDKit::ROMol mol, bool onlyHeavy=False)
# NumValenceElectrons 'Atom' object has no attribute 'GetAtoms'
# NumRadicalElectrons 'Atom' object has no attribute 'GetAtoms'
# MaxPartialCharge Python argument types in
#     rdkit.Chem.rdPartialCharges.ComputeGasteigerCharges(Atom)
# did not match C++ signature:
#     ComputeGasteigerCharges(RDKit::ROMol mol, int nIter=12, bool throwOnParamFailure=False)
# MinPartialCharge Python argument types in
#     rdkit.Chem.rdPartialCharges.ComputeGasteigerCharges(Atom)
# did not match C++ signature:
#     ComputeGasteigerCharges(RDKit::ROMol mol, int nIter=12, bool throwOnParamFailure=False)
# MaxAbsPartialCharge Python argument types in
#     rdkit.Chem.rdPartialCharges.ComputeGasteigerCharges(Atom)
# did not match C++ signature:
#     ComputeGasteigerCharges(RDKit::ROMol mol, int nIter=12, bool throwOnParamFailure=False)
# MinAbsPartialCharge Python argument types in
#     rdkit.Chem.rdPartialCharges.ComputeGasteigerCharges(Atom)
# did not match C++ signature:
#     ComputeGasteigerCharges(RDKit::ROMol mol, int nIter=12, bool throwOnParamFailure=False)
# FpDensityMorgan1 Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(Atom, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# FpDensityMorgan2 Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(Atom, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# FpDensityMorgan3 Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(Atom, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# names 'list' object is not callable
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI') nan
# ...
# SetBondStereoFromDirections Python argument types in
#     rdkit.Chem.rdmolops.SetBondStereoFromDirections(Atom)
# did not match C++ signature:
#     SetBondStereoFromDirections(RDKit::ROMol {lvalue} mol)
# GetSSSR Python argument types in
#     rdkit.Chem.rdmolops.GetSSSR(Atom)
# did not match C++ signature:
#     GetSSSR(RDKit::ROMol {lvalue})
# GetSymmSSSR Python argument types in
#     rdkit.Chem.rdmolops.GetSymmSSSR(Atom)
# did not match C++ signature:
#     GetSymmSSSR(RDKit::ROMol {lvalue})
# SetTerminalAtomCoords Python argument types in
#     rdkit.Chem.rdmolops.SetTerminalAtomCoords(Atom)
# did not match C++ signature:
#     SetTerminalAtomCoords(RDKit::ROMol {lvalue}, unsigned int, unsigned int)
# FastFindRings Python argument types in
#     rdkit.Chem.rdmolops.FastFindRings(Atom)
# did not match C++ signature:
#     FastFindRings(RDKit::ROMol)
# FindRingFamilies Python argument types in
#     rdkit.Chem.rdmolops.FindRingFamilies(Atom)
# did not match C++ signature:
#     FindRingFamilies(RDKit::ROMol)
# AddHs Python argument types in
#     rdkit.Chem.rdmolops.AddHs(Atom)
# did not match C++ signature:
#     AddHs(RDKit::ROMol mol, bool explicitOnly=False, bool addCoords=False, boost::python::api::object onlyOnAtoms=None, bool addResidueInfo=False)
# RemoveHs Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(Atom)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True)
# RemoveHsParameters Python argument types in
#     RemoveHsParameters.__init__(RemoveHsParameters, Atom)
# did not match C++ signature:
#     __init__(_object*)
# RemoveAllHs Python argument types in
#     rdkit.Chem.rdmolops.RemoveAllHs(Atom)
# did not match C++ signature:
#     RemoveAllHs(RDKit::ROMol mol, bool sanitize=True)
# MergeQueryHs Python argument types in
#     rdkit.Chem.rdmolops.MergeQueryHs(Atom)
# did not match C++ signature:
#     MergeQueryHs(RDKit::ROMol mol, bool mergeUnmappedOnly=False)
# DeleteSubstructs Python argument types in
#     rdkit.Chem.rdmolops.DeleteSubstructs(Atom)
# did not match C++ signature:
#     DeleteSubstructs(RDKit::ROMol mol, RDKit::ROMol query, bool onlyFrags=False, bool useChirality=False)
# MurckoDecompose Python argument types in
#     rdkit.Chem.rdmolops.MurckoDecompose(Atom)
# did not match C++ signature:
#     MurckoDecompose(RDKit::ROMol mol)
# CombineMols Python argument types in
#     rdkit.Chem.rdmolops.CombineMols(Atom)
# did not match C++ signature:
#     CombineMols(RDKit::ROMol mol1, RDKit::ROMol mol2, RDGeom::Point3D offset=<rdkit.Geometry.rdGeometry.Point3D object at 0x7f7d70449500>)
# ReplaceSubstructs Python argument types in
#     rdkit.Chem.rdmolops.ReplaceSubstructs(Atom)
# did not match C++ signature:
#     ReplaceSubstructs(RDKit::ROMol mol, RDKit::ROMol query, RDKit::ROMol replacement, bool replaceAll=False, unsigned int replacementConnectionPoint=0, bool useChirality=False)
# GetMostSubstitutedCoreMatch Python argument types in
#     rdkit.Chem.rdmolops.GetMostSubstitutedCoreMatch(Atom)
# did not match C++ signature:
#     GetMostSubstitutedCoreMatch(RDKit::ROMol mol, RDKit::ROMol core, boost::python::api::object matches)
# SortMatchesByDegreeOfCoreSubstitution Python argument types in
#     rdkit.Chem.rdmolops.SortMatchesByDegreeOfCoreSubstitution(Atom)
# did not match C++ signature:
#     SortMatchesByDegreeOfCoreSubstitution(RDKit::ROMol mol, RDKit::ROMol core, boost::python::api::object matches)
# MolAddRecursiveQueries Python argument types in
#     rdkit.Chem.rdmolops.MolAddRecursiveQueries(Atom)
# did not match C++ signature:
#     MolAddRecursiveQueries(RDKit::ROMol {lvalue} mol, boost::python::dict queries, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > propName)
# ParseMolQueryDefFile That Python file object has no 'read' attribute
# GetDistanceMatrix Python argument types in
#     rdkit.Chem.rdmolops.GetDistanceMatrix(Atom)
# did not match C++ signature:
#     GetDistanceMatrix(RDKit::ROMol {lvalue} mol, bool useBO=False, bool useAtomWts=False, bool force=False, char const* prefix='')
# Get3DDistanceMatrix Python argument types in
#     rdkit.Chem.rdmolops.Get3DDistanceMatrix(Atom)
# did not match C++ signature:
#     Get3DDistanceMatrix(RDKit::ROMol {lvalue} mol, int confId=-1, bool useAtomWts=False, bool force=False, char const* prefix='')
# GetAdjacencyMatrix Python argument types in
#     rdkit.Chem.rdmolops.GetAdjacencyMatrix(Atom)
# did not match C++ signature:
#     GetAdjacencyMatrix(RDKit::ROMol {lvalue} mol, bool useBO=False, int emptyVal=0, bool force=False, char const* prefix='')
# Kekulize Python argument types in
#     rdkit.Chem.rdmolops.Kekulize(Atom)
# did not match C++ signature:
#     Kekulize(RDKit::ROMol {lvalue} mol, bool clearAromaticFlags=False)
# Cleanup Python argument types in
#     rdkit.Chem.rdmolops.Cleanup(Atom)
# did not match C++ signature:
#     Cleanup(RDKit::ROMol {lvalue} mol)
# AromaticityModel int() argument must be a string, a bytes-like object or a number, not 'Atom'
# AROMATICITY_DEFAULT 'AromaticityModel' object is not callable
# AROMATICITY_RDKIT 'AromaticityModel' object is not callable
# AROMATICITY_SIMPLE 'AromaticityModel' object is not callable
# AROMATICITY_MDL 'AromaticityModel' object is not callable
# AROMATICITY_CUSTOM 'AromaticityModel' object is not callable
# SetAromaticity Python argument types in
#     rdkit.Chem.rdmolops.SetAromaticity(Atom)
# did not match C++ signature:
#     SetAromaticity(RDKit::ROMol {lvalue} mol, RDKit::MolOps::AromaticityModel model=rdkit.Chem.rdmolops.AromaticityModel.AROMATICITY_DEFAULT)
# SetConjugation Python argument types in
#     rdkit.Chem.rdmolops.SetConjugation(Atom)
# did not match C++ signature:
#     SetConjugation(RDKit::ROMol {lvalue} mol)
# SetHybridization Python argument types in
#     rdkit.Chem.rdmolops.SetHybridization(Atom)
# did not match C++ signature:
#     SetHybridization(RDKit::ROMol {lvalue} mol)
# AssignRadicals Python argument types in
#     rdkit.Chem.rdmolops.AssignRadicals(Atom)
# did not match C++ signature:
#     AssignRadicals(RDKit::ROMol {lvalue} mol)
# FindAllSubgraphsOfLengthN Python argument types in
#     rdkit.Chem.rdmolops.FindAllSubgraphsOfLengthN(Atom)
# did not match C++ signature:
#     FindAllSubgraphsOfLengthN(RDKit::ROMol mol, unsigned int length, bool useHs=False, int rootedAtAtom=-1)
# FindAllSubgraphsOfLengthMToN Python argument types in
#     rdkit.Chem.rdmolops.FindAllSubgraphsOfLengthMToN(Atom)
# did not match C++ signature:
#     FindAllSubgraphsOfLengthMToN(RDKit::ROMol mol, unsigned int min, unsigned int max, bool useHs=False, int rootedAtAtom=-1)
# FindUniqueSubgraphsOfLengthN Python argument types in
#     rdkit.Chem.rdmolops.FindUniqueSubgraphsOfLengthN(Atom)
# did not match C++ signature:
#     FindUniqueSubgraphsOfLengthN(RDKit::ROMol mol, unsigned int length, bool useHs=False, bool useBO=True, int rootedAtAtom=-1)
# FindAllPathsOfLengthN Python argument types in
#     rdkit.Chem.rdmolops.FindAllPathsOfLengthN(Atom)
# did not match C++ signature:
#     FindAllPathsOfLengthN(RDKit::ROMol mol, unsigned int length, bool useBonds=True, bool useHs=False, int rootedAtAtom=-1)
# FindAtomEnvironmentOfRadiusN Python argument types in
#     rdkit.Chem.rdmolops.FindAtomEnvironmentOfRadiusN(Atom)
# did not match C++ signature:
#     FindAtomEnvironmentOfRadiusN(RDKit::ROMol mol, unsigned int radius, unsigned int rootedAtAtom, bool useHs=False)
# PathToSubmol Python argument types in
#     rdkit.Chem.rdmolops.PathToSubmol(Atom)
# did not match C++ signature:
#     PathToSubmol(RDKit::ROMol mol, boost::python::api::object {lvalue} path, bool useQuery=False, boost::python::api::object atomMap=None)
# GetMolFrags Python argument types in
#     rdkit.Chem.rdmolops.GetMolFrags(Atom)
# did not match C++ signature:
#     GetMolFrags(RDKit::ROMol mol, bool asMols=False, bool sanitizeFrags=True, boost::python::api::object frags=None, boost::python::api::object fragsMolAtomMapping=None)
# GetFormalCharge Python argument types in
#     rdkit.Chem.rdmolops.GetFormalCharge(Atom)
# did not match C++ signature:
#     GetFormalCharge(RDKit::ROMol)
# GetShortestPath Python argument types in
#     rdkit.Chem.rdmolops.GetShortestPath(Atom)
# did not match C++ signature:
#     GetShortestPath(RDKit::ROMol, int, int)
# AssignStereochemistry Python argument types in
#     rdkit.Chem.rdmolops.AssignStereochemistry(Atom)
# did not match C++ signature:
#     AssignStereochemistry(RDKit::ROMol {lvalue} mol, bool cleanIt=False, bool force=False, bool flagPossibleStereoCenters=False)
# AssignChiralTypesFromBondDirs Python argument types in
#     rdkit.Chem.rdmolops.AssignChiralTypesFromBondDirs(Atom)
# did not match C++ signature:
#     AssignChiralTypesFromBondDirs(RDKit::ROMol {lvalue} mol, int confId=-1, bool replaceExistingTags=True)
# AssignStereochemistryFrom3D Python argument types in
#     rdkit.Chem.rdmolops.AssignStereochemistryFrom3D(Atom)
# did not match C++ signature:
#     AssignStereochemistryFrom3D(RDKit::ROMol {lvalue} mol, int confId=-1, bool replaceExistingTags=True)
# FindPotentialStereoBonds Python argument types in
#     rdkit.Chem.rdmolops.FindPotentialStereoBonds(Atom)
# did not match C++ signature:
#     FindPotentialStereoBonds(RDKit::ROMol {lvalue} mol, bool cleanIt=False)
# RemoveStereochemistry Python argument types in
#     rdkit.Chem.rdmolops.RemoveStereochemistry(Atom)
# did not match C++ signature:
#     RemoveStereochemistry(RDKit::ROMol {lvalue} mol)
# AssignAtomChiralTagsFromStructure Python argument types in
#     rdkit.Chem.rdmolops.AssignAtomChiralTagsFromStructure(Atom)
# did not match C++ signature:
#     AssignAtomChiralTagsFromStructure(RDKit::ROMol {lvalue} mol, int confId=-1, bool replaceExistingTags=True)
# AssignAtomChiralTagsFromMolParity Python argument types in
#     rdkit.Chem.rdmolops.AssignAtomChiralTagsFromMolParity(Atom)
# did not match C++ signature:
#     AssignAtomChiralTagsFromMolParity(RDKit::ROMol {lvalue} mol, bool replaceExistingTags=True)
# RDKFingerprint Python argument types in
#     rdkit.Chem.rdmolops.RDKFingerprint(Atom)
# did not match C++ signature:
#     RDKFingerprint(RDKit::ROMol mol, unsigned int minPath=1, unsigned int maxPath=7, unsigned int fpSize=2048, unsigned int nBitsPerHash=2, bool useHs=True, double tgtDensity=0.0, unsigned int minSize=128, bool branchedPaths=True, bool useBondOrder=True, boost::python::api::object atomInvariants=0, boost::python::api::object fromAtoms=0, boost::python::api::object atomBits=None, boost::python::api::object bitInfo=None)
# UnfoldedRDKFingerprintCountBased Python argument types in
#     rdkit.Chem.rdmolops.UnfoldedRDKFingerprintCountBased(Atom)
# did not match C++ signature:
#     UnfoldedRDKFingerprintCountBased(RDKit::ROMol mol, unsigned int minPath=1, unsigned int maxPath=7, bool useHs=True, bool branchedPaths=True, bool useBondOrder=True, boost::python::api::object atomInvariants=0, boost::python::api::object fromAtoms=0, boost::python::api::object atomBits=None, boost::python::api::object bitInfo=None)
# LayeredFingerprint Python argument types in
#     rdkit.Chem.rdmolops.LayeredFingerprint(Atom)
# did not match C++ signature:
#     LayeredFingerprint(RDKit::ROMol mol, unsigned int layerFlags=4294967295, unsigned int minPath=1, unsigned int maxPath=7, unsigned int fpSize=2048, boost::python::list atomCounts=[], ExplicitBitVect* setOnlyBits=None, bool branchedPaths=True, boost::python::api::object fromAtoms=0)
# LayeredFingerprint_substructLayers 'int' object is not callable
# PatternFingerprint Python argument types in
#     rdkit.Chem.rdmolops.PatternFingerprint(Atom)
# did not match C++ signature:
#     PatternFingerprint(RDKit::MolBundle mol, unsigned int fpSize=2048, ExplicitBitVect* setOnlyBits=None, bool tautomerFingerprints=False)
#     PatternFingerprint(RDKit::ROMol mol, unsigned int fpSize=2048, boost::python::list atomCounts=[], ExplicitBitVect* setOnlyBits=None, bool tautomerFingerprints=False)
# WedgeMolBonds Python argument types in
#     rdkit.Chem.rdmolops.WedgeMolBonds(Atom)
# did not match C++ signature:
#     WedgeMolBonds(RDKit::ROMol {lvalue}, RDKit::Conformer const*)
# WedgeBond Python argument types in
#     rdkit.Chem.rdmolops.WedgeBond(Atom)
# did not match C++ signature:
#     WedgeBond(RDKit::Bond*, unsigned int, RDKit::Conformer const*)
# ReplaceSidechains Python argument types in
#     rdkit.Chem.rdmolops.ReplaceSidechains(Atom)
# did not match C++ signature:
#     ReplaceSidechains(RDKit::ROMol mol, RDKit::ROMol coreQuery, bool useChirality=False)
# ReplaceCore Python argument types in
#     rdkit.Chem.rdmolops.ReplaceCore(Atom)
# did not match C++ signature:
#     ReplaceCore(RDKit::ROMol mol, RDKit::ROMol coreQuery, bool replaceDummies=True, bool labelByIndex=False, bool requireDummyMatch=False, bool useChirality=False)
#     ReplaceCore(RDKit::ROMol mol, RDKit::ROMol core, boost::python::api::object matches, bool replaceDummies=True, bool labelByIndex=False, bool requireDummyMatch=False)
# FragmentOnBRICSBonds Python argument types in
#     rdkit.Chem.rdmolops.FragmentOnBRICSBonds(Atom)
# did not match C++ signature:
#     FragmentOnBRICSBonds(RDKit::ROMol mol)
# FragmentOnBonds Python argument types in
#     rdkit.Chem.rdmolops.FragmentOnBonds(Atom)
# did not match C++ signature:
#     FragmentOnBonds(RDKit::ROMol mol, boost::python::api::object bondIndices, bool addDummies=True, boost::python::api::object dummyLabels=None, boost::python::api::object bondTypes=None, boost::python::list cutsPerAtom=[])
# FragmentOnSomeBonds Python argument types in
#     rdkit.Chem.rdmolops.FragmentOnSomeBonds(Atom)
# did not match C++ signature:
#     FragmentOnSomeBonds(RDKit::ROMol mol, boost::python::api::object bondIndices, unsigned int numToBreak=1, bool addDummies=True, boost::python::api::object dummyLabels=None, boost::python::api::object bondTypes=None, bool returnCutsPerAtom=False)
# MolzipLabel int() argument must be a string, a bytes-like object or a number, not 'Atom'
# MolzipParams Python argument types in
#     MolzipParams.__init__(MolzipParams, Atom)
# did not match C++ signature:
#     __init__(_object*)
# molzip Python argument types in
#     rdkit.Chem.rdmolops.molzip(Atom)
# did not match C++ signature:
#     molzip(RDKit::ROMol a, RDKit::MolzipParams params=<rdkit.Chem.rdmolops.MolzipParams object at 0x7f7d704496c0>)
#     molzip(RDKit::ROMol a, RDKit::ROMol b, RDKit::MolzipParams params=<rdkit.Chem.rdmolops.MolzipParams object at 0x7f7d70449650>)
# AddRecursiveQuery Python argument types in
#     rdkit.Chem.rdmolops.AddRecursiveQuery(Atom)
# did not match C++ signature:
#     AddRecursiveQuery(RDKit::ROMol {lvalue} mol, RDKit::ROMol query, unsigned int atomIdx, bool preserveExistingQuery=True)
# RenumberAtoms Python argument types in
#     rdkit.Chem.rdmolops.RenumberAtoms(Atom)
# did not match C++ signature:
#     RenumberAtoms(RDKit::ROMol mol, boost::python::api::object {lvalue} newOrder)
# AdjustQueryWhichFlags int() argument must be a string, a bytes-like object or a number, not 'Atom'
# ADJUST_IGNORENONE 'AdjustQueryWhichFlags' object is not callable
# ADJUST_IGNORECHAINS 'AdjustQueryWhichFlags' object is not callable
# ADJUST_IGNORERINGS 'AdjustQueryWhichFlags' object is not callable
# ADJUST_IGNOREDUMMIES 'AdjustQueryWhichFlags' object is not callable
# ADJUST_IGNORENONDUMMIES 'AdjustQueryWhichFlags' object is not callable
# ADJUST_IGNOREALL 'AdjustQueryWhichFlags' object is not callable
# AdjustQueryParameters Python argument types in
#     AdjustQueryParameters.__init__(AdjustQueryParameters, Atom)
# did not match C++ signature:
#     __init__(_object*)
# AdjustQueryProperties Python argument types in
#     rdkit.Chem.rdmolops.AdjustQueryProperties(Atom)
# did not match C++ signature:
#     AdjustQueryProperties(RDKit::ROMol mol, boost::python::api::object params=None)
# DetectChemistryProblems Python argument types in
#     rdkit.Chem.rdmolops.DetectChemistryProblems(Atom)
# did not match C++ signature:
#     DetectChemistryProblems(RDKit::ROMol mol, unsigned int sanitizeOps=rdkit.Chem.rdmolops.SanitizeFlags.SANITIZE_ALL)
# FindPotentialStereo Python argument types in
#     rdkit.Chem.rdmolops.FindPotentialStereo(Atom)
# did not match C++ signature:
#     FindPotentialStereo(RDKit::ROMol {lvalue} mol, bool cleanIt=False, bool flagPossible=True)

# %%
try:os.remove(data_to_work_pckl,)
except FileNotFoundError:pass
try:os.remove(sucsess_mods_pckl)
except FileNotFoundError:pass
try:os.remove(unsucsess_mods_pckl)
except FileNotFoundError:pass
len(sucsess_mods)
sucsess_mods
# Out:
# {('rdkit.Chem.Descriptors', 'BCUT2D_CHGHI'),
#  ('rdkit.Chem.Descriptors', 'BCUT2D_CHGLO'),
#  ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPHI'),
#  ('rdkit.Chem.Descriptors', 'BCUT2D_LOGPLOW'),
#  ('rdkit.Chem.Descriptors', 'BCUT2D_MRHI'),
#  ('rdkit.Chem.Descriptors', 'BCUT2D_MRLOW'),
#  ('rdkit.Chem.Descriptors', 'BCUT2D_MWHI'),
#  ('rdkit.Chem.Descriptors', 'BCUT2D_MWLOW'),
#  ('rdkit.Chem.Descriptors', 'Chi1'),
#  ('rdkit.Chem.GraphDescriptors', 'Chi1'),
#  ('rdkit.Chem.rdMolDescriptors', 'GetAtomPairAtomCode')}

# %%
succs=[]
for mod_name, func_name in sucsess_mods:
    mod=modules[mod_name]
    f=getattr(mod,func_name)
    if any([f==getattr(black_mod,func_name,None) for black_mod in BLACK_LIST_MODULES]):
        continue
    s = {
        "func_name":func_name,
        "func":f,
        "module":mod_name,
    }
    already_in=False
    for ss in succs:
        if s["func_name"]==ss["func_name"] and s["module"]==ss["module"]:
            already_in=True
            break
    if already_in:
        continue
    succs.append(s)

def check_memberf(func_name):
    try:
        def f(_atom):
            return getattr(_atom,func_name)()
        res=f(Chem.Mol(testmols[0]).GetAtoms()[0])
        if res is None:
            return
        succs.append({
            'func_name':func_name,
            "func":f,
            'module': 'self',
        })
        print(func_name)
        #print(res)
       #print("-"*20)
    except Exception:
        pass
for func_name in dir(testmols[0].GetAtoms()[0]):
    if func_name in SELF_IGNORES:
        continue
    check_memberf(func_name)
    #print(func_name)
len(succs)
SELF_IGNORES
# Out:
# GetAtomMapNum
# GetAtomicNum
# GetChiralTag
# GetDegree
# GetExplicitValence
# GetFormalCharge
# GetHybridization
# GetImplicitValence
# GetIsAromatic
# GetIsotope
# GetMass
# GetNoImplicit
# GetNumExplicitHs
# GetNumImplicitHs
# GetNumRadicalElectrons
# GetSymbol
# GetTotalDegree
# GetTotalNumHs
# GetTotalValence
# IsInRing
# ['DescribeQuery',
#  'GetBonds',
#  'GetIdx',
#  'GetNeighbors',
#  'GetOwningMol',
#  'GetPropNames',
#  'GetPropsAsDict',
#  'NeedsUpdatePropertyCache',
#  'GetSmarts',
#  '__copy__',
#  '__dir__',
#  '__hash__',
#  '__repr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'HasQuery',
#  'HasOwningMol']

# %%
succs
# Out:
# [{'func_name': 'BCUT2D_CHGLO',
#   'func': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_CHGLO(mol, index=3)>,
#   'module': 'rdkit.Chem.Descriptors'},
#  {'func_name': 'Chi1',
#   'func': <function rdkit.Chem.GraphDescriptors.Chi1(mol)>,
#   'module': 'rdkit.Chem.Descriptors'},
#  {'func_name': 'BCUT2D_MRLOW',
#   'func': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_MRLOW(mol, index=7)>,
#   'module': 'rdkit.Chem.Descriptors'},
#  {'func_name': 'Chi1',
#   'func': <function rdkit.Chem.GraphDescriptors.Chi1(mol)>,
#   'module': 'rdkit.Chem.GraphDescriptors'},
#  {'func_name': 'BCUT2D_MRHI',
#   'func': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_MRHI(mol, index=6)>,
#   'module': 'rdkit.Chem.Descriptors'},
#  {'func_name': 'BCUT2D_LOGPHI',
#   'func': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_LOGPHI(mol, index=4)>,
#   'module': 'rdkit.Chem.Descriptors'},
#  {'func_name': 'BCUT2D_LOGPLOW',
#   'func': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_LOGPLOW(mol, index=5)>,
#   'module': 'rdkit.Chem.Descriptors'},
#  {'func_name': 'BCUT2D_CHGHI',
#   'func': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_CHGHI(mol, index=2)>,
#   'module': 'rdkit.Chem.Descriptors'},
#  {'func_name': 'BCUT2D_MWHI',
#   'func': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_MWHI(mol, index=0)>,
#   'module': 'rdkit.Chem.Descriptors'},
#  {'func_name': 'BCUT2D_MWLOW',
#   'func': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_MWLOW(mol, index=1)>,
#   'module': 'rdkit.Chem.Descriptors'},
#  {'func_name': 'GetAtomPairAtomCode',
#   'func': <function rdkit.Chem.rdMolDescriptors.GetAtomPairAtomCode>,
#   'module': 'rdkit.Chem.rdMolDescriptors'},
#  {'func_name': 'GetAtomMapNum',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'GetAtomicNum',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'GetChiralTag',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'GetDegree',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'GetExplicitValence',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'GetFormalCharge',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'GetHybridization',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'GetImplicitValence',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'GetIsAromatic',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'GetIsotope',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'GetMass',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'GetNoImplicit',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'GetNumExplicitHs',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'GetNumImplicitHs',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'GetNumRadicalElectrons',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'GetSymbol',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'GetTotalDegree',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'GetTotalNumHs',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'GetTotalValence',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'},
#  {'func_name': 'IsInRing',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self'}]

# %%
from rdkit.DataStructs.cDataStructs import ConvertToNumpyArray

MAX_LENGTH=4096

loded_funcs=[]
for s in succs[::-1]:
    n=s["func_name"]
    f=s["func"]
    #if f in loded_funcs:
    #    continue
    loded_funcs.append(f)
    #print(n)
    def try_f(mol):
        try:
            #print("Call",n,end=" ")
            ats=list(mol.GetAtoms())
            return f(ats[int(len(ats)/2)])
             
        except Exception as e:
            display(mol)
            display(s)
            print(Chem.MolToSmiles(mol))
            raise e
       # print("done")
    #f=try_f
    r=try_f(Chem.Mol(testmols[0]))
    #print(n,f,r)
    #break
    data=[r]
    if r is None:
        s["type"]="none"
        continue
    elif isinstance(r,(Chem.Mol,Chem.EditableMol)):
        s["type"]="mol"
        continue
    elif isinstance(r,(Exception)):
        s["type"]="exception"
        continue
    elif isinstance(r,(int,float)):
        s["type"]="numeric"
        s["length_type"]="independend_length"
        s["length"]=1  
    elif isinstance(r,(str)):
        s["type"]="string"
        continue
    elif isinstance(r,(list,tuple)):
        
        l1=len(r)
        if l1==0:
            s["type"]="unknown"
            continue
            
        if isinstance(r[0],(int,float)):
            pass
        else:
            s["type"]="unknown"
            continue
        s["type"]="list"
        l1=len(r)
        s["length_type"]=None
        for m in testmols:
            r2=f(m)
            l2=len(r2)
            if l1!=l2:
                s["length_type"]="dependend_length"
                break
            data.append(r2)
        
        if s["length_type"] == None:
            s["length_type"]="independend_length"
            s["length"]=l1  
    
    
    elif isinstance(r,(np.ndarray)): 
        s["type"]="numpy_arrays"
        s["dtype"]="np."+str(r.dtype)
        s["length_type"]=None
        if len(r.flatten())>MAX_LENGTH:
            s["length_type"]="too_long"
            continue
        else:
            for m in testmols:
                r2=f(m)
                if r.shape!=r2.shape:
                    s["length_type"]="dependend_length"
                    break
                data.append(r2)
                
            if s["length_type"] == None:
                s["length_type"]="independend_length"
                s["length"]=r.flatten().shape[0] 
            else:
                continue
                
    elif r.__class__.__name__.endswith("Vect"):
        #print(n,dir(r))
        s["type"]="rdkit_vec"
        s["length_type"]=None
        try:
            l=r.GetLength()
        except:
            l=len(r)
        if l>MAX_LENGTH:
            print(l,"lengt")
            s["length_type"]="too_long"
            continue
        else: 
            for m in testmols:
                r2=f(m)
                try:
                    l2=r2.GetLength()
                except:
                    l2=len(r2)

                if l!=l2:
                    s["length_type"]="dependend_length"
                    break
                data.append(r2)
            
            if s["length_type"] == None:
                s["length_type"]="independend_length"
                s["length"]=l  
                if  r.__class__.__name__.endswith("IntVect"):
                    if "long" in r.__class__.__name__.lower():
                        s["dtype"]="np.int64"
                    else:
                        s["dtype"]="np.int32"
                    continue
                elif r.__class__.__name__.endswith("BitVect"):
                    s["dtype"]="np.int32"
                    continue
            else:
                continue
    else:
        s["type"]="unknown"
        continue
    
    #print(n)
    if len(data)!=len(testmols):
        data = [np.array(try_f(m)) for m in testmols]
        
    if len(data)!=len(testmols):
        raise ValueError(len(data),len(testmols))
    #print(data)
    #print(s)
    #print(data)
    if s["length_type"] == "independend_length":
        a = np.stack(data)
    else:
        a = np.array(data)
    #print(a)
    if a.dtype != object:
        if a.dtype == float:
            if np.isnan(a).all():
                s["type"]="unknown"
                continue
            try:
                np.array(a, dtype=np.float32)
                s["dtype"]="np.float32"
            except OverflowError:
                s["dtype"]="np.float64"
        elif a.dtype == int:
            try:
                np.array(a, dtype=np.int32)
                s["dtype"]="np.int32"
            except OverflowError:
                s["dtype"]="np.int64"
        else:
            s["dtype"]="np."+str(a.dtype)
    else:
        #print([i.dtype for i in a])
        dt=np.unique(np.array([i.dtype for i in a]))
        if len(dt)==1:
            dt = dt[0]
            s["dtype"]="np."+str(dt)
        else:
            print("AAA",dt)
            print(n,a)
    #print(n,s["dtype"])
succs
# Out:
# [{'func_name': 'BCUT2D_CHGLO',
#   'func': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_CHGLO(mol, index=3)>,
#   'module': 'rdkit.Chem.Descriptors',
#   'type': 'unknown',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.float32',
#   'classname': 'BCUT2D_CHGLO_Featurizer',
#   'red_name': 'BCUT2D_CHGLO',
#   'code': 'class  BCUT2D_CHGLO_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.float32\n    featurize=staticmethod(BCUT2D_CHGLO)\n    # normalization\n    # functions\n    \n    '},
#  {'func_name': 'Chi1',
#   'func': <function rdkit.Chem.GraphDescriptors.Chi1(mol)>,
#   'module': 'rdkit.Chem.Descriptors',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.float32',
#   'classname': 'Chi1_Featurizer',
#   'red_name': 'Chi1',
#   'code': 'class  Chi1_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.float32\n    featurize=staticmethod(Chi1)\n    # normalization\n    # functions\n    \n    '},
#  {'func_name': 'BCUT2D_MRLOW',
#   'func': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_MRLOW(mol, index=7)>,
#   'module': 'rdkit.Chem.Descriptors',
#   'type': 'unknown',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.float32',
#   'classname': 'BCUT2D_MRLOW_Featurizer',
#   'red_name': 'BCUT2D_MRLOW',
#   'code': 'class  BCUT2D_MRLOW_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.float32\n    featurize=staticmethod(BCUT2D_MRLOW)\n    # normalization\n    # functions\n    \n    '},
#  {'func_name': 'Chi1',
#   'func': <function rdkit.Chem.GraphDescriptors.Chi1(mol)>,
#   'module': 'rdkit.Chem.GraphDescriptors',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.float32',
#   'classname': 'Chi1_Featurizer',
#   'red_name': 'Chi1',
#   'code': 'class  Chi1_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.float32\n    featurize=staticmethod(Chi1)\n    # normalization\n    # functions\n    \n    '},
#  {'func_name': 'BCUT2D_MRHI',
#   'func': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_MRHI(mol, index=6)>,
#   'module': 'rdkit.Chem.Descriptors',
#   'type': 'unknown',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.float32',
#   'classname': 'BCUT2D_MRHI_Featurizer',
#   'red_name': 'BCUT2D_MRHI',
#   'code': 'class  BCUT2D_MRHI_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.float32\n    featurize=staticmethod(BCUT2D_MRHI)\n    # normalization\n    # functions\n    \n    '},
#  {'func_name': 'BCUT2D_LOGPHI',
#   'func': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_LOGPHI(mol, index=4)>,
#   'module': 'rdkit.Chem.Descriptors',
#   'type': 'unknown',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.float32',
#   'classname': 'BCUT2D_LOGPHI_Featurizer',
#   'red_name': 'BCUT2D_LOGPHI',
#   'code': 'class  BCUT2D_LOGPHI_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.float32\n    featurize=staticmethod(BCUT2D_LOGPHI)\n    # normalization\n    # functions\n    \n    '},
#  {'func_name': 'BCUT2D_LOGPLOW',
#   'func': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_LOGPLOW(mol, index=5)>,
#   'module': 'rdkit.Chem.Descriptors',
#   'type': 'unknown',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.float32',
#   'classname': 'BCUT2D_LOGPLOW_Featurizer',
#   'red_name': 'BCUT2D_LOGPLOW',
#   'code': 'class  BCUT2D_LOGPLOW_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.float32\n    featurize=staticmethod(BCUT2D_LOGPLOW)\n    # normalization\n    # functions\n    \n    '},
#  {'func_name': 'BCUT2D_CHGHI',
#   'func': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_CHGHI(mol, index=2)>,
#   'module': 'rdkit.Chem.Descriptors',
#   'type': 'unknown',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.float32',
#   'classname': 'BCUT2D_CHGHI_Featurizer',
#   'red_name': 'BCUT2D_CHGHI',
#   'code': 'class  BCUT2D_CHGHI_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.float32\n    featurize=staticmethod(BCUT2D_CHGHI)\n    # normalization\n    # functions\n    \n    '},
#  {'func_name': 'BCUT2D_MWHI',
#   'func': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_MWHI(mol, index=0)>,
#   'module': 'rdkit.Chem.Descriptors',
#   'type': 'unknown',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.float32',
#   'classname': 'BCUT2D_MWHI_Featurizer',
#   'red_name': 'BCUT2D_MWHI',
#   'code': 'class  BCUT2D_MWHI_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.float32\n    featurize=staticmethod(BCUT2D_MWHI)\n    # normalization\n    # functions\n    \n    '},
#  {'func_name': 'BCUT2D_MWLOW',
#   'func': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_MWLOW(mol, index=1)>,
#   'module': 'rdkit.Chem.Descriptors',
#   'type': 'unknown',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.float32',
#   'classname': 'BCUT2D_MWLOW_Featurizer',
#   'red_name': 'BCUT2D_MWLOW',
#   'code': 'class  BCUT2D_MWLOW_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.float32\n    featurize=staticmethod(BCUT2D_MWLOW)\n    # normalization\n    # functions\n    \n    '},
#  {'func_name': 'GetAtomPairAtomCode',
#   'func': <function rdkit.Chem.rdMolDescriptors.GetAtomPairAtomCode>,
#   'module': 'rdkit.Chem.rdMolDescriptors',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.int32',
#   'classname': 'AtomPairAtomCode_Featurizer',
#   'red_name': 'AtomPairAtomCode',
#   'code': 'class  AtomPairAtomCode_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.int32\n    featurize=staticmethod(GetAtomPairAtomCode)\n    # normalization\n    # functions\n    \n    '},
#  {'func_name': 'GetAtomMapNum',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.int32',
#   'classname': 'AtomMapNum_Featurizer',
#   'red_name': 'AtomMapNum',
#   'code': 'class  AtomMapNum_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.int32\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.GetAtomMapNum()\n    '},
#  {'func_name': 'GetAtomicNum',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.int32',
#   'classname': 'AtomicNum_Featurizer',
#   'red_name': 'AtomicNum',
#   'code': 'class  AtomicNum_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.int32\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.GetAtomicNum()\n    '},
#  {'func_name': 'GetChiralTag',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.int32',
#   'classname': 'ChiralTag_Featurizer',
#   'red_name': 'ChiralTag',
#   'code': 'class  ChiralTag_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.int32\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.GetChiralTag()\n    '},
#  {'func_name': 'GetDegree',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.int32',
#   'classname': 'Degree_Featurizer',
#   'red_name': 'Degree',
#   'code': 'class  Degree_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.int32\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.GetDegree()\n    '},
#  {'func_name': 'GetExplicitValence',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.int32',
#   'classname': 'ExplicitValence_Featurizer',
#   'red_name': 'ExplicitValence',
#   'code': 'class  ExplicitValence_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.int32\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.GetExplicitValence()\n    '},
#  {'func_name': 'GetFormalCharge',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.int32',
#   'classname': 'FormalCharge_Featurizer',
#   'red_name': 'FormalCharge',
#   'code': 'class  FormalCharge_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.int32\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.GetFormalCharge()\n    '},
#  {'func_name': 'GetHybridization',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.int32',
#   'classname': 'Hybridization_Featurizer',
#   'red_name': 'Hybridization',
#   'code': 'class  Hybridization_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.int32\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.GetHybridization()\n    '},
#  {'func_name': 'GetImplicitValence',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.int32',
#   'classname': 'ImplicitValence_Featurizer',
#   'red_name': 'ImplicitValence',
#   'code': 'class  ImplicitValence_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.int32\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.GetImplicitValence()\n    '},
#  {'func_name': 'GetIsAromatic',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.bool',
#   'classname': 'IsAromatic_Featurizer',
#   'red_name': 'IsAromatic',
#   'code': 'class  IsAromatic_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.bool\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.GetIsAromatic()\n    '},
#  {'func_name': 'GetIsotope',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.int32',
#   'classname': 'Isotope_Featurizer',
#   'red_name': 'Isotope',
#   'code': 'class  Isotope_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.int32\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.GetIsotope()\n    '},
#  {'func_name': 'GetMass',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.float32',
#   'classname': 'Mass_Featurizer',
#   'red_name': 'Mass',
#   'code': 'class  Mass_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.float32\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.GetMass()\n    '},
#  {'func_name': 'GetNoImplicit',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.bool',
#   'classname': 'NoImplicit_Featurizer',
#   'red_name': 'NoImplicit',
#   'code': 'class  NoImplicit_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.bool\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.GetNoImplicit()\n    '},
#  {'func_name': 'GetNumExplicitHs',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.int32',
#   'classname': 'NumExplicitHs_Featurizer',
#   'red_name': 'NumExplicitHs',
#   'code': 'class  NumExplicitHs_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.int32\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.GetNumExplicitHs()\n    '},
#  {'func_name': 'GetNumImplicitHs',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.int32',
#   'classname': 'NumImplicitHs_Featurizer',
#   'red_name': 'NumImplicitHs',
#   'code': 'class  NumImplicitHs_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.int32\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.GetNumImplicitHs()\n    '},
#  {'func_name': 'GetNumRadicalElectrons',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.int32',
#   'classname': 'NumRadicalElectrons_Featurizer',
#   'red_name': 'NumRadicalElectrons',
#   'code': 'class  NumRadicalElectrons_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.int32\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.GetNumRadicalElectrons()\n    '},
#  {'func_name': 'GetSymbol',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'string',
#   'classname': 'Symbol_Featurizer',
#   'red_name': 'Symbol'},
#  {'func_name': 'GetTotalDegree',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.int32',
#   'classname': 'TotalDegree_Featurizer',
#   'red_name': 'TotalDegree',
#   'code': 'class  TotalDegree_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.int32\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.GetTotalDegree()\n    '},
#  {'func_name': 'GetTotalNumHs',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.int32',
#   'classname': 'TotalNumHs_Featurizer',
#   'red_name': 'TotalNumHs',
#   'code': 'class  TotalNumHs_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.int32\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.GetTotalNumHs()\n    '},
#  {'func_name': 'GetTotalValence',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.int32',
#   'classname': 'TotalValence_Featurizer',
#   'red_name': 'TotalValence',
#   'code': 'class  TotalValence_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.int32\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.GetTotalValence()\n    '},
#  {'func_name': 'IsInRing',
#   'func': <function __main__.check_memberf.<locals>.f(_atom)>,
#   'module': 'self',
#   'type': 'numeric',
#   'length_type': 'independend_length',
#   'length': 1,
#   'dtype': 'np.bool',
#   'classname': 'IsInRing_Featurizer',
#   'red_name': 'IsInRing',
#   'code': 'class  IsInRing_Featurizer(SingleValueAtomFeaturizer):\n    # statics\n    dtype=np.bool\n    # normalization\n    # functions\n    def featurize(self,atom):\n        return atom.IsInRing()\n    '}]

# %%
for s in succs:
    if s["module"]=="self":
        print(s['func_name'])
# Out:
# GetAtomMapNum
# GetAtomicNum
# GetChiralTag
# GetDegree
# GetExplicitValence
# GetFormalCharge
# GetHybridization
# GetImplicitValence
# GetIsAromatic
# GetIsotope
# GetMass
# GetNoImplicit
# GetNumExplicitHs
# GetNumImplicitHs
# GetNumRadicalElectrons
# GetSymbol
# GetTotalDegree
# GetTotalNumHs
# GetTotalValence
# IsInRing

# %%
#valid
#numeric
#independend_length
#int_vec
#bit_vec, 1
#numpy_arrays

#invalid
#dependend_length
#stringf
#too_long_vec
#none_returned
#mol_returned
#exception_returned
#unknown
#numeric
#dtypes

#succs

# %%
data_folder="atom_ecdf_data"
os.makedirs(data_folder,exist_ok=True)
df_cont=os.listdir(data_folder)
avail_norms= [f.replace(".data","") for f in df_cont if ".data" in f]
avail_norms=[f for f in avail_norms if f+".data" in df_cont]
avail_norms=[f for f in avail_norms if f+".ecdf" in df_cont]
len(avail_norms)
# Out:
# 33

# %%
from collections import defaultdict
def reduce_name(n):
    red_name=n
    if red_name.startswith("Calc"):
        red_name=red_name[4:]
    if red_name.startswith("Get"):
        red_name=red_name[3:]
    return red_name

for ss in succs:
    if 'red_name' in ss:
        del ss['red_name']
    if 'code' in ss:
        del ss['code']

for s in succs:
    s['red_name']=reduce_name(s['func_name'])
    s['classname']=f"{s['red_name']}_Featurizer"

# %%
    
imports=defaultdict(lambda:defaultdict(lambda:set()))

def numeric_coder(s):
    class_string_numeric="""class  {classname}(SingleValueAtomFeaturizer):
    # statics
    dtype={dtype}
    featurize=staticmethod({classcall})
    # normalization
    # functions
    
    """
    
    
   
    f1=s['func']
    mod_name1 = s['module']
    if mod_name1=="self":
        class_string_numeric="""class  {classname}(SingleValueAtomFeaturizer):
    # statics
    dtype={dtype}
    # normalization
    # functions
    def featurize(self,atom):
        return atom.{classcall}()
    """
        
    for ss in succs:
        if ss == s:
            continue
        if 'red_name' in ss:
            if ss["red_name"] == s["red_name"]:
                r1=f1(Chem.Mol(testmols[0]).GetAtoms()[0])
                f2=ss['func']
                mod_name2 = ss['module']
                r2=f2(Chem.Mol(testmols[0]).GetAtoms()[0])
                if r1!=r2:
                    raise ValueError("doublefunc ({},{})".format(s,ss))
                else:
                    #print(s)
                    #print(ss)
                    #print()
                    continue
    imports[s['type']][s['module']].add(s['func_name'])

    code=class_string_numeric.format(classname=s["classname"],
                                     classcall=s["func_name"],
                                     dtype=s['dtype']
                                    )
    
    
    if s["classname"] in avail_norms:
        #print(s["classname"])
        with open(os.path.join(data_folder,s["classname"]+".data"),"r") as f:
            ecdf_data=json.load(f)["0"]
        idx = code.index("# normalization")+len("# normalization")
        precode=code[:idx]+"\n"
        postcode=code[idx:]

        best=None
        for datakey,parakey,best_key in [
            ("linear_norm","linear_norm_parameter", "linear"),
            ("min_max_norm","min_max_norm_parameter","min_max"),
            ("sig_norm","sigmoidal_norm_parameter","sig"),
            ("dual_sig_norm","dual_sigmoidal_norm_parameter", "dual_sig"),
            ("genlog_norm","genlog_norm_parameter","genlog"),
        ]:
            if datakey in ecdf_data:
                norm_data=ecdf_data[datakey]
                precode+=f"    {parakey} = ({', '.join([str(i) for i in norm_data['parameter']])})"+\
                f"  # error of {norm_data['error']:.2E} with sample range ({norm_data['sample_bounds'][0][0]:.2E},{norm_data['sample_bounds'][0][1]:.2E}) resulting in fit range ({norm_data['sample_bounds'][1][0]:.2E},{norm_data['sample_bounds'][1][1]:.2E})\n"
        
            if 'sample_bounds99' not in norm_data or norm_data['sample_bounds'][0][0] == norm_data['sample_bounds'][0][1]:
                best = ("unity",0,norm_data['sample_bounds'])
            else:
                if norm_data['sample_bounds'][1][0]<=0.3 and norm_data['sample_bounds'][1][1]>0.5:
                    if best is None:
                        best = (best_key,norm_data['error'],norm_data['sample_bounds'])
                    else:
                        if norm_data['error']<best[1]:
                            best = (best_key,norm_data['error'],norm_data['sample_bounds'])

        if best is not None:
            precode+=f"    preferred_normalization = '{best[0]}'"
        code=precode+postcode
    s["code"]=code
    #print(code)
    


def rdkit_vec_coder(s):
    mod_name1 = s['module']
    if mod_name1=="self":
        raise NotImplementedError()
    if s['length_type']=='independend_length':
        class_string="""class  {classname}(FixedSizeFeaturizer,AtomFeaturizer):
    # statics
    LENGTH = {length}
    dtype={dtype}
    # normalization
    # functions
    def featurize(self,atom):
        a=np.zeros(len(self),dtype=self.dtype)
        ConvertToNumpyArray({classcall}(atom),a)
        return a
        """
        code=class_string.format(classname=s["classname"],
                                     classcall=s["func_name"],
                                     dtype=s['dtype'],
                                 length=s["length"]
                                    )
    elif s['length_type']=='dependend_length':
        class_string="""class  {classname}(AtomFeaturizer):
    # statics
    dtype={dtype}
    # normalization
    # functions
    
    def featurize(self,atom):
        r={classcall}(atom)
        try:
            l=r.GetLength()
        except:
            l=len(r)
            
        a=np.zeros(len(self),dtype=self.dtype)
        ConvertToNumpyArray(r,a)
        return a
        """
        code=class_string.format(classname=s["classname"],
                                     classcall=s["func_name"],
                                     dtype=s['dtype'],
                                    )
    elif s['length_type']=='too_long':
        return
    else:
        print(s)
        raise NotImplementedError(s['length_type'])
    
    imports[s['type']][s['module']].add(s['func_name'])
    s["code"]=code    

    
def list_coder(s):
    mod_name1 = s['module']
    if mod_name1=="self":
        raise NotImplementedError()
    if s['length_type']=='independend_length':
        class_string="""class  {classname}(FixedSizeFeaturizer,AtomFeaturizer):
    # statics
    LENGTH = {length}
    dtype={dtype}
    featurize=staticmethod({classcall})
    # normalization
    # functions
        """
        code=class_string.format(classname=s["classname"],
                                     classcall=s["func_name"],
                                     dtype=s['dtype'],
                                 length=s["length"]
                                    )
    elif s['length_type']=='dependend_length':
        class_string="""class {classname}(AtomFeaturizer):
    # statics
    dtype={dtype}
    
    featurize=staticmethod({classcall})
    # normalization
    # functions
        """
        code=class_string.format(classname=s["classname"],
                                     classcall=s["func_name"],
                                     dtype=s['dtype'],
                                    )
    elif s['length_type']=='too_long':
        return
    else:
        print(s)
        raise NotImplementedError(s['length_type'])
    imports[s['type']][s['module']].add(s['func_name'])
    s["code"]=code    

def numpy_arrays_coder(s):
    mod_name1 = s['module']
    if mod_name1=="self":
        raise NotImplementedError() 
    if s['length_type']=='independend_length':
        class_string="""class  {classname}(FixedSizeFeaturizer,AtomFeaturizer):
    # statics
    LENGTH = {length}
    dtype={dtype}
    # normalization
    # functions
    
    def featurize(self,atom):
        return {classcall}(atom).flatten()
        """
        code=class_string.format(classname=s["classname"],
                                     classcall=s["func_name"],
                                     dtype=s['dtype'],
                                 length=s["length"]
                                    )
    elif s['length_type']=='dependend_length':
        class_string="""class {classname}(AtomFeaturizer):
    # statics
    dtype={dtype}
    # normalization
    # functions
    
    def featurize(self,atom):
        return {classcall}(atom).flatten()
        """
        code=class_string.format(classname=s["classname"],
                                     classcall=s["func_name"],
                                     dtype=s['dtype'],
                                    )
        
    elif s['length_type']=='too_long':
        return
    else:
        print(s)
        raise NotImplementedError(s['length_type'])
    imports[s['type']][s['module']].add(s['func_name'])
    s["code"]=code    

def get_coder(t):
    if t=="none":
        return None
    elif t=="numeric":
        return numeric_coder
    elif t=="rdkit_vec":
        return rdkit_vec_coder
    elif t=="list":
        return list_coder
    elif t=="mol":
        return None
    elif t=="unknown":
        return None
    elif t=="numpy_arrays":
        return numpy_arrays_coder
    elif t=="string":
        return None
    else:
        raise ValueError("missing coder for "+str(t))


for s in succs:
    coder = get_coder(s['type'])
    if coder:
        coder(s)

# %%
sheets={}
for s in succs:
    if "code" in s:
        #print(s["code"])
        if s['type'] not in sheets:
            sheets[s['type']]= []
        sheets[s['type']].append(s)

# %%
for s,d in sheets.items():
    full_code="from molNet.featurizer._atom_featurizer import AtomFeaturizer,SingleValueAtomFeaturizer\n"
    full_code+="from molNet.featurizer.featurizer import FixedSizeFeaturizer\n"
    full_code+="import numpy as np\n"
    full_code+="from rdkit.DataStructs.cDataStructs import ConvertToNumpyArray\n"
    for k,v in imports[s].items():
        if k == "self":
            continue
        full_code+="from {} import ({},)\n".format(k,",".join(v))
    full_code+="\n"*2
    
    for ss in d:
        full_code+=ss["code"]+"\n\n"
    
   
    
    available_featurizer=[]
    for ss in d:
        red_name=ss['red_name']
        sn="atom_"+red_name
        available_featurizer.append(sn)
        full_code+="{}={}()\n".format(sn,red_name+"_Featurizer")

    full_code+="\n"
    full_code+="_available_featurizer={{\n{}\n}}\n".format(",\n".join(["'{}':{}".format(af,af) for af in available_featurizer]))

    full_code+="""\n\n\n
def main():
    from rdkit import Chem
    testmol=Chem.MolFromSmiles("c1ccccc1")
    for k,f in _available_featurizer.items():
        print(k)
        f(testmol.GetAtoms()[0])

if __name__=='__main__':
    main()
    """
    #print(full_code)
    autogen_file=f"_autogen_atom_featurizer_{s}.py"
    with open(autogen_file,"w+") as f:
        f.write(full_code)

full_code=""
for s,d in sheets.items():
    full_code+=f"from ._autogen_atom_featurizer_{s} import *\n"
    full_code+=f"from ._autogen_atom_featurizer_{s} import (\n"
    full_code+=f"     _available_featurizer as _available_featurizer_{s},\n)\n"
full_code+="\n_available_featurizer = {\n"
full_code+="\n".join([f"    **_available_featurizer_{s}," for s,d in sheets.items()])
full_code+="\n}"

autogen_file=f"_autogen_atom_featurizer.py"
with open(autogen_file,"w+") as f:
    f.write(full_code)

# %%
from molNet.featurizer.atom_featurizer import SingleValueAtomFeaturizer, _available_featurizer
from molNet.featurizer.featurizer import FeaturizerList 

class AllSingleValueAtomFeaturizer(FeaturizerList):
    def __init__(self,*args,**kwargs):
        super().__init__([f for f in _available_featurizer.values() if isinstance(f,SingleValueAtomFeaturizer)],*args,**kwargs)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-104-0f1fd70022e9> in <module>
# ----> 1 from molNet.featurizer.atom_featurizer import SingleValueAtomFeaturizer, _available_featurizer
#       2 from molNet.featurizer.featurizer import FeaturizerList
#       3
#       4 class AllSingleValueAtomFeaturizer(FeaturizerList):
#       5     def __init__(self,*args,**kwargs):
#
# ImportError: cannot import name '_available_featurizer' from 'molNet.featurizer.atom_featurizer' (/home/julian/anaconda3/envs/graph_chem_unit/lib/python3.8/site-packages/molNet/featurizer/atom_featurizer.py)

# %%
import rdkit
f=AllSingleValueAtomFeaturizer()(rdkit.Chem.MolFromSmiles("c1cc(N)ccc1C(C)C"))

# %%
f.max()
# Out:
# 0.99999976

# %%
import numpy as np
(np.concatenate([np.ones(1,dtype=np.uint32),np.ones(1,dtype=np.uint16)])).dtype
# Out:
# dtype('uint32')
